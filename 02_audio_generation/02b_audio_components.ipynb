# %%
# !pip install gtts pydub audioop-lts
from gtts import gTTS
from pydub import AudioSegment
import time
import os
import pandas as pd
import glob
from collections import defaultdict
pd.options.display.max_columns = 100

# %% [markdown]
# # 1. Load data

# %%
cols_keep = [
    'chinese', 'pinyin', 'english',
    'type', 'priority', 'known', 'known_pinyin_prompt', 'known_english_prompt',
    'phonetic', 'category1', 'quality',
    'word1', 'word1_english', 'word2', 'word2_english', 'word3', 'word3_english', 'word4', 'word4_english',
    'sentence', 'sentence_pinyin', 'sentence_english', 'date']
sheet_url = 'https://docs.google.com/spreadsheets/d/1pw9EAIvtiWenPDBFBIf7pwTh0FvIbIR0c3mY5gJwlDk/edit#gid=0'
sheet_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')
df = pd.read_csv(sheet_url)[cols_keep]
df = df.dropna(subset=['chinese', 'english'])
df['known_english_prompt'] = df['known_english_prompt'].fillna(6)
print(df.shape)
df.head()
# Out:
# (4565, 23)
#   chinese         pinyin              english   type  priority  known  \
# 0     后备箱  hòu bèi xiāng  trunk;boot (of car)  combo       1.0    5.0
# 1      爆竹        bào zhú          firecracker  combo       1.0    3.0
# 2      周一        zhōu yī               monday  combo       1.0    1.0
# 3      一月         yī yuè              january  combo       1.0    1.0
# 4      黄金      huáng jīn                 gold  combo       1.0    1.0
#
#    known_pinyin_prompt  known_english_prompt  phonetic category1  quality  \
# 0                  1.0                   3.0       NaN    travel      1.0
# 1                  2.0                   5.0       NaN     china      1.0
# 2                  1.0                   1.0       NaN   general      1.0
# 3                  1.0                   1.0       NaN   general      1.0
# 4                  1.0                   1.0       NaN  industry      1.0
#
#   word1 word1_english word2 word2_english word3 word3_english word4  \
# 0     后          back    设备     equipment     箱           box   NaN
# 1     爆       explode     竹        bamboo   NaN           NaN   NaN
# 2     周          week     一           one   NaN           NaN   NaN
# 3     一           one     月         month   NaN           NaN   NaN
# 4     黄        yellow     金         metal   NaN           NaN   NaN
#
#   word4_english        sentence  \
# 0           NaN        把行李放进后备箱
# 1           NaN  春节的时候我们放了很多爆竹。
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
#
#                                    sentence_pinyin  \
# 0                   Bǎ xínglǐ fàng jìn hòubèixiāng
# 1  Chūnjié de shíhou wǒmen fàng le hěn duō bàozhú.
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#                                     sentence_english date
# 0                       Put the luggage in the trunk  NaN
# 1  We set off many firecrackers during Spring Fes...  NaN
# 2                                                NaN  NaN
# 3                                                NaN  NaN
# 4                                                NaN  NaN

# %% [markdown]
# # 2. Select data

# %%
# Which data to use this time?
types_not_allowed = ['phrase', 'sentence', 'part sent', 'phrase_save']
df_this = (
    df[
        (df['priority'] <= 2) &
        (df['known_english_prompt'] >= 2) &
        (~df['type'].isin(types_not_allowed))
    ]
    .sort_values(['category1', 'pinyin'], ascending=[True, True])
    .dropna(subset=['word1', 'word1_english', 'word2', 'word2_english'])
    .reset_index(drop=True))
print(df_this.shape)
df_this.head(10)
# Out:
# (912, 23)
#   chinese       pinyin                 english   type  priority  known  \
# 0      标准    biāo zhǔn                standard  combo       1.0    5.0
# 1      出名     chū míng                  famous  combo       2.0    5.0
# 2      大声     dà shēng                    loud  combo       2.0    4.0
# 3      角度     jiǎo​ dù                   angle  combo       2.0    3.0
# 4      主动     zhǔ dòng  initiative;voluntarily  combo       2.0    5.0
# 5      主观     zhǔ guān              subjective  combo       2.0    5.0
# 6      自愿      zì yuàn               voluntary  combo       2.0    5.0
# 7      百万      bǎi wàn                 million  combo       2.0    2.0
# 8     差不多   chà bù duō     almost;more or less  combo       2.0    2.0
# 9     差点儿  chà diǎn er                  almost  combo       2.0    2.0
#
#    known_pinyin_prompt  known_english_prompt  phonetic  category1  quality  \
# 0                  1.0                   3.0       NaN  adjective      3.0
# 1                  2.0                   2.0       NaN  adjective      2.0
# 2                  5.0                   2.0       NaN  adjective      1.0
# 3                  1.0                   5.0       NaN  adjective      2.0
# 4                  5.0                   5.0       NaN  adjective      2.0
# 5                  5.0                   5.0       NaN  adjective      2.0
# 6                  5.0                   5.0       NaN  adjective      2.0
# 7                  1.0                   2.0       NaN     amount      3.0
# 8                  1.0                   3.0       NaN     amount      3.0
# 9                  2.0                   2.0       NaN     amount      2.0
#
#   word1 word1_english word2  word2_english word3 word3_english word4  \
# 0    目标        target    准备    preparation   NaN           NaN   NaN
# 1     出     to go out     名           name   NaN           NaN   NaN
# 2     大           big     声          voice   NaN           NaN   NaN
# 3     角          horn    程度         degree   NaN           NaN   NaN
# 4    主意          plan    动作       movement   NaN           NaN   NaN
# 5    主义      ideology    观点  point of view   NaN           NaN   NaN
# 6     自          self    愿意           wish   NaN           NaN   NaN
# 7     百       hundred     万   ten thousand   NaN           NaN   NaN
# 8    差异    difference     不             no     多          much   NaN
# 9     差       lacking     点            bit     儿    Beijing er   NaN
#
#   word4_english    sentence                          sentence_pinyin  \
# 0           NaN   这家店的服务很标准        Zhè jiā diàn de fúwù hěn biāozhǔn
# 1           NaN  他因为短视频很快出名   Tā yīnwèi duǎn shìpín hěn kuài chūmíng
# 2           NaN     请不要大声说话               Qǐng búyào dàshēng shuōhuà
# 3           NaN      换个角度看看                    Huàn gè jiǎodù kànkan
# 4           NaN     她主动打了招呼                  Tā zhǔdòng dǎ le zhāohu
# 5           NaN    这是你的主观感受            Zhè shì nǐ de zhǔguān gǎnshòu
# 6           NaN       我自愿帮忙                       Wǒ zìyuàn bāngmáng
# 7           NaN  他中了彩票奖金是百万  Tā zhòng le cǎipiào jiǎngjīn shì bǎiwàn
# 8           NaN   我们俩的想法差不多            Wǒmen liǎ de xiǎngfǎ chàbuduō
# 9           NaN   我差点儿错过了火车             Wǒ chàdiǎnr cuòguò le huǒchē
#
#                                    sentence_english        date
# 0                 The service here is very standard         NaN
# 1  He became famous quickly because of short videos         NaN
# 2                        Please do not speak loudly  2025-06-15
# 3                     Look at it from another angle         NaN
# 4                              She greeted me first         NaN
# 5                   This is your subjective feeling         NaN
# 6                               I volunteer to help         NaN
# 7                 He won a million from the lottery         NaN
# 8                Our ideas are pretty much the same         NaN
# 9                         I almost missed the train         NaN

# %% [markdown]
# # 3. TTS

# %%
def create_tts_file(tts_type, content_str, lang_name, last_timestamp):
    if tts_type == 'zh_slow':
        slow_mode = True
    else:
        slow_mode = False

    new_file_path = f"audio_files/{tts_type}/{content_str}.mp3"
    if not os.path.exists(new_file_path):
        try:
            gTTS(content_str, lang=lang_name, slow=slow_mode).save(new_file_path)
        except:
            # Wait 60 seconds and try again
            print(f"!!!!!!! FAILURE, wait 52 seconds, row{i_row}, {tts_type}, {content_str} !!!!!!!")
            time.sleep(52)
            try:
                gTTS(content_str, lang=lang_name, slow=slow_mode).save(new_file_path)
            except:
                # Wait 60 seconds and try again
                print(f"!!!!!!!!!! FAILURE AGAIN, wait 278 seconds, row{i_row}, {tts_type}, {content_str} !!!!!!!!!!")
                time.sleep(278)
                gTTS(content_str, lang=lang_name, slow=slow_mode).save(new_file_path)
        print(f"{(time.time()-last_timestamp):.3f}s, row{i_row}, {tts_type}, {content_str}")
    else:
        print(f"{(time.time()-last_timestamp):.3f}s, ALREADY EXISTS, row{i_row}, {tts_type}, {content_str}")


for i_row, row in df_this.iterrows():
    create_tts_file(tts_type='zh', content_str=row['chinese'], lang_name='zh-cn', last_timestamp=time.time())
    create_tts_file(tts_type='zh_slow', content_str=row['chinese'], lang_name='zh-cn', last_timestamp=time.time())
    create_tts_file(tts_type='english', content_str=row['english'], lang_name='en', last_timestamp=time.time())
    create_tts_file(tts_type='zh', content_str=row['word1'], lang_name='zh-cn', last_timestamp=time.time())
    create_tts_file(tts_type='zh', content_str=row['word2'], lang_name='zh-cn', last_timestamp=time.time())
    create_tts_file(tts_type='english', content_str=row['word1_english'], lang_name='en', last_timestamp=time.time())
    create_tts_file(tts_type='english', content_str=row['word2_english'], lang_name='en', last_timestamp=time.time())
    if not pd.isna(row['word3']):
        create_tts_file(tts_type='zh', content_str=row['word3'], lang_name='zh-cn', last_timestamp=time.time())
        create_tts_file(tts_type='english', content_str=row['word3_english'], lang_name='en', last_timestamp=time.time())
    if not pd.isna(row['word4']):
        create_tts_file(tts_type='zh', content_str=row['word4'], lang_name='zh-cn', last_timestamp=time.time())
        create_tts_file(tts_type='english', content_str=row['word4_english'], lang_name='en', last_timestamp=time.time())
# Out:
# 0.000s, ALREADY EXISTS, row0, zh, 标准
# 0.000s, ALREADY EXISTS, row0, zh_slow, 标准
# 0.000s, ALREADY EXISTS, row0, english, standard
# 0.000s, ALREADY EXISTS, row0, zh, 目标
# 0.000s, ALREADY EXISTS, row0, zh, 准备
# 0.000s, ALREADY EXISTS, row0, english, target
# 0.000s, ALREADY EXISTS, row0, english, preparation
# 0.000s, ALREADY EXISTS, row1, zh, 出名
# 0.000s, ALREADY EXISTS, row1, zh_slow, 出名
# 0.000s, ALREADY EXISTS, row1, english, famous
# 0.000s, ALREADY EXISTS, row1, zh, 出
# 0.000s, ALREADY EXISTS, row1, zh, 名
# 0.000s, ALREADY EXISTS, row1, english, to go out
# 0.000s, ALREADY EXISTS, row1, english, name
# 0.000s, ALREADY EXISTS, row2, zh, 大声
# 0.000s, ALREADY EXISTS, row2, zh_slow, 大声
# 0.000s, ALREADY EXISTS, row2, english, loud
# 0.000s, ALREADY EXISTS, row2, zh, 大
# 0.000s, ALREADY EXISTS, row2, zh, 声
# 0.000s, ALREADY EXISTS, row2, english, big
# 0.000s, ALREADY EXISTS, row2, english, voice
# 0.000s, ALREADY EXISTS, row3, zh, 角度
# 0.000s, ALREADY EXISTS, row3, zh_slow, 角度
# 0.000s, ALREADY EXISTS, row3, english, angle
# 0.000s, ALREADY EXISTS, row3, zh, 角
# 0.000s, ALREADY EXISTS, row3, zh, 程度
# 0.000s, ALREADY EXISTS, row3, english, horn
# 0.000s, ALREADY EXISTS, row3, english, degree
# 0.000s, ALREADY EXISTS, row4, zh, 主动
# 0.000s, ALREADY EXISTS, row4, zh_slow, 主动
# 0.000s, ALREADY EXISTS, row4, english, initiative;voluntarily
# 0.000s, ALREADY EXISTS, row4, zh, 主意
# 0.000s, ALREADY EXISTS, row4, zh, 动作
# 0.000s, ALREADY EXISTS, row4, english, plan
# 0.000s, ALREADY EXISTS, row4, english, movement
# 0.000s, ALREADY EXISTS, row5, zh, 主观
# 0.000s, ALREADY EXISTS, row5, zh_slow, 主观
# 0.000s, ALREADY EXISTS, row5, english, subjective
# 0.000s, ALREADY EXISTS, row5, zh, 主义
# 0.000s, ALREADY EXISTS, row5, zh, 观点
# 0.000s, ALREADY EXISTS, row5, english, ideology
# 0.000s, ALREADY EXISTS, row5, english, point of view
# 0.000s, ALREADY EXISTS, row6, zh, 自愿
# 0.000s, ALREADY EXISTS, row6, zh_slow, 自愿
# 0.000s, ALREADY EXISTS, row6, english, voluntary
# 0.000s, ALREADY EXISTS, row6, zh, 自
# 0.000s, ALREADY EXISTS, row6, zh, 愿意
# 0.000s, ALREADY EXISTS, row6, english, self
# 0.000s, ALREADY EXISTS, row6, english, wish
# 0.000s, ALREADY EXISTS, row7, zh, 百万
# 0.000s, ALREADY EXISTS, row7, zh_slow, 百万
# 0.000s, ALREADY EXISTS, row7, english, million
# 0.000s, ALREADY EXISTS, row7, zh, 百
# 0.000s, ALREADY EXISTS, row7, zh, 万
# 0.000s, ALREADY EXISTS, row7, english, hundred
# 0.000s, ALREADY EXISTS, row7, english, ten thousand
# 0.000s, ALREADY EXISTS, row8, zh, 差不多
# 0.000s, ALREADY EXISTS, row8, zh_slow, 差不多
# 0.000s, ALREADY EXISTS, row8, english, almost;more or less
# 0.000s, ALREADY EXISTS, row8, zh, 差异
# 0.000s, ALREADY EXISTS, row8, zh, 不
# 0.000s, ALREADY EXISTS, row8, english, difference
# 0.000s, ALREADY EXISTS, row8, english, no
# 0.000s, ALREADY EXISTS, row8, zh, 多
# 0.000s, ALREADY EXISTS, row8, english, much
# 0.000s, ALREADY EXISTS, row9, zh, 差点儿
# 0.000s, ALREADY EXISTS, row9, zh_slow, 差点儿
# 0.000s, ALREADY EXISTS, row9, english, almost
# 0.000s, ALREADY EXISTS, row9, zh, 差
# 0.000s, ALREADY EXISTS, row9, zh, 点
# 0.000s, ALREADY EXISTS, row9, english, lacking
# 0.000s, ALREADY EXISTS, row9, english, bit
# 0.000s, ALREADY EXISTS, row9, zh, 儿
# 0.000s, ALREADY EXISTS, row9, english, Beijing er
# 0.000s, ALREADY EXISTS, row10, zh, 差距
# 0.000s, ALREADY EXISTS, row10, zh_slow, 差距
# 0.000s, ALREADY EXISTS, row10, english, gap
# 0.000s, ALREADY EXISTS, row10, zh, 差
# 0.000s, ALREADY EXISTS, row10, zh, 距离
# 0.000s, ALREADY EXISTS, row10, english, to differ
# 0.000s, ALREADY EXISTS, row10, english, distance
# 0.000s, ALREADY EXISTS, row11, zh, 大部分
# 0.000s, ALREADY EXISTS, row11, zh_slow, 大部分
# 0.000s, ALREADY EXISTS, row11, english, most
# 0.000s, ALREADY EXISTS, row11, zh, 大
# 0.000s, ALREADY EXISTS, row11, zh, 部分
# 0.000s, ALREADY EXISTS, row11, english, big
# 0.000s, ALREADY EXISTS, row11, english, part
# 0.000s, ALREADY EXISTS, row12, zh, 大多数
# 0.000s, ALREADY EXISTS, row12, zh_slow, 大多数
# 0.000s, ALREADY EXISTS, row12, english, majority
# 0.000s, ALREADY EXISTS, row12, zh, 大
# 0.000s, ALREADY EXISTS, row12, zh, 多
# 0.000s, ALREADY EXISTS, row12, english, big
# 0.000s, ALREADY EXISTS, row12, english, many
# 0.000s, ALREADY EXISTS, row12, zh, 数
# 0.000s, ALREADY EXISTS, row12, english, number
# 0.000s, ALREADY EXISTS, row13, zh, 大概
# 0.000s, ALREADY EXISTS, row13, zh_slow, 大概
# 0.000s, ALREADY EXISTS, row13, english, probably
# 0.000s, ALREADY EXISTS, row13, zh, 大
# 0.000s, ALREADY EXISTS, row13, zh, 概念
# 0.000s, ALREADY EXISTS, row13, english, big
# 0.000s, ALREADY EXISTS, row13, english, concept
# 0.000s, ALREADY EXISTS, row14, zh, 大小
# 0.000s, ALREADY EXISTS, row14, zh_slow, 大小
# 0.000s, ALREADY EXISTS, row14, english, size
# 0.000s, ALREADY EXISTS, row14, zh, 大
# 0.000s, ALREADY EXISTS, row14, zh, 小
# 0.000s, ALREADY EXISTS, row14, english, big
# 0.000s, ALREADY EXISTS, row14, english, small
# 0.000s, ALREADY EXISTS, row15, zh, 概率
# 0.000s, ALREADY EXISTS, row15, zh_slow, 概率
# 0.000s, ALREADY EXISTS, row15, english, probability
# 0.000s, ALREADY EXISTS, row15, zh, 大概
# 0.000s, ALREADY EXISTS, row15, zh, 率
# 0.000s, ALREADY EXISTS, row15, english, roughly
# 0.000s, ALREADY EXISTS, row15, english, rate
# 0.000s, ALREADY EXISTS, row16, zh, 高度
# 0.000s, ALREADY EXISTS, row16, zh_slow, 高度
# 0.000s, ALREADY EXISTS, row16, english, altitude
# 0.000s, ALREADY EXISTS, row16, zh, 高
# 0.000s, ALREADY EXISTS, row16, zh, 度
# 0.000s, ALREADY EXISTS, row16, english, high
# 0.000s, ALREADY EXISTS, row16, english, degree;measure
# 0.000s, ALREADY EXISTS, row17, zh, 好几
# 0.000s, ALREADY EXISTS, row17, zh_slow, 好几
# 0.000s, ALREADY EXISTS, row17, english, several
# 0.000s, ALREADY EXISTS, row17, zh, 好
# 0.000s, ALREADY EXISTS, row17, zh, 几个
# 0.000s, ALREADY EXISTS, row17, english, good
# 0.000s, ALREADY EXISTS, row17, english, a few
# 0.000s, ALREADY EXISTS, row18, zh, 几十
# 0.000s, ALREADY EXISTS, row18, zh_slow, 几十
# 0.000s, ALREADY EXISTS, row18, english, dozens
# 0.000s, ALREADY EXISTS, row18, zh, 几
# 0.000s, ALREADY EXISTS, row18, zh, 十
# 0.000s, ALREADY EXISTS, row18, english, several
# 0.000s, ALREADY EXISTS, row18, english, ten
# 0.000s, ALREADY EXISTS, row19, zh, 毛重
# 0.000s, ALREADY EXISTS, row19, zh_slow, 毛重
# 0.000s, ALREADY EXISTS, row19, english, gross weight
# 0.000s, ALREADY EXISTS, row19, zh, 毛
# 0.000s, ALREADY EXISTS, row19, zh, 重量
# 0.000s, ALREADY EXISTS, row19, english, hair
# 0.000s, ALREADY EXISTS, row19, english, weight
# 0.000s, ALREADY EXISTS, row20, zh, 难得
# 0.000s, ALREADY EXISTS, row20, zh_slow, 难得
# 0.000s, ALREADY EXISTS, row20, english, rare;seldom
# 0.000s, ALREADY EXISTS, row20, zh, 难
# 0.000s, ALREADY EXISTS, row20, zh, 得
# 0.000s, ALREADY EXISTS, row20, english, hard
# 0.000s, ALREADY EXISTS, row20, english, to get
# 0.000s, ALREADY EXISTS, row21, zh, 频率
# 0.000s, ALREADY EXISTS, row21, zh_slow, 频率
# 0.000s, ALREADY EXISTS, row21, english, frequency
# 0.000s, ALREADY EXISTS, row21, zh, 视频
# 0.000s, ALREADY EXISTS, row21, zh, 率
# 0.000s, ALREADY EXISTS, row21, english, video
# 0.000s, ALREADY EXISTS, row21, english, rate
# 0.000s, ALREADY EXISTS, row22, zh, 平方米
# 0.000s, ALREADY EXISTS, row22, zh_slow, 平方米
# 0.000s, ALREADY EXISTS, row22, english, square meter
# 0.000s, ALREADY EXISTS, row22, zh, 平
# 0.000s, ALREADY EXISTS, row22, zh, 方
# 0.000s, ALREADY EXISTS, row22, english, flat
# 0.000s, ALREADY EXISTS, row22, english, square
# 0.000s, ALREADY EXISTS, row22, zh, 米
# 0.000s, ALREADY EXISTS, row22, english, meter
# 0.000s, ALREADY EXISTS, row23, zh, 十亿
# 0.000s, ALREADY EXISTS, row23, zh_slow, 十亿
# 0.000s, ALREADY EXISTS, row23, english, billion
# 0.000s, ALREADY EXISTS, row23, zh, 十
# 0.000s, ALREADY EXISTS, row23, zh, 亿
# 0.000s, ALREADY EXISTS, row23, english, ten
# 0.000s, ALREADY EXISTS, row23, english, hundred million
# 0.000s, ALREADY EXISTS, row24, zh, 数量
# 0.000s, ALREADY EXISTS, row24, zh_slow, 数量
# 0.000s, ALREADY EXISTS, row24, english, quantity;amount
# 0.000s, ALREADY EXISTS, row24, zh, 数
# 0.000s, ALREADY EXISTS, row24, zh, 量
# 0.000s, ALREADY EXISTS, row24, english, number
# 0.000s, ALREADY EXISTS, row24, english, measure
# 0.000s, ALREADY EXISTS, row25, zh, 微克
# 0.000s, ALREADY EXISTS, row25, zh_slow, 微克
# 0.000s, ALREADY EXISTS, row25, english, microgram
# 0.000s, ALREADY EXISTS, row25, zh, 微
# 0.000s, ALREADY EXISTS, row25, zh, 克
# 0.000s, ALREADY EXISTS, row25, english, tiny
# 0.000s, ALREADY EXISTS, row25, english, gram
# 0.000s, ALREADY EXISTS, row26, zh, 至少
# 0.000s, ALREADY EXISTS, row26, zh_slow, 至少
# 0.000s, ALREADY EXISTS, row26, english, at least
# 0.000s, ALREADY EXISTS, row26, zh, 至
# 0.000s, ALREADY EXISTS, row26, zh, 少
# 0.000s, ALREADY EXISTS, row26, english, until
# 0.000s, ALREADY EXISTS, row26, english, few
# 0.000s, ALREADY EXISTS, row27, zh, 重量
# 0.000s, ALREADY EXISTS, row27, zh_slow, 重量
# 0.000s, ALREADY EXISTS, row27, english, weight
# 0.000s, ALREADY EXISTS, row27, zh, 重
# 0.000s, ALREADY EXISTS, row27, zh, 量
# 0.000s, ALREADY EXISTS, row27, english, heavy
# 0.000s, ALREADY EXISTS, row27, english, measure
# 0.000s, ALREADY EXISTS, row28, zh, 左右
# 0.000s, ALREADY EXISTS, row28, zh_slow, 左右
# 0.000s, ALREADY EXISTS, row28, english, approximately;about;around
# 0.000s, ALREADY EXISTS, row28, zh, 左
# 0.000s, ALREADY EXISTS, row28, zh, 右
# 0.000s, ALREADY EXISTS, row28, english, left
# 0.000s, ALREADY EXISTS, row28, english, right
# 0.000s, ALREADY EXISTS, row29, zh, 八爪鱼
# 0.000s, ALREADY EXISTS, row29, zh_slow, 八爪鱼
# 0.000s, ALREADY EXISTS, row29, english, octopus
# 0.000s, ALREADY EXISTS, row29, zh, 八
# 0.000s, ALREADY EXISTS, row29, zh, 爪
# 0.000s, ALREADY EXISTS, row29, english, eight
# 0.000s, ALREADY EXISTS, row29, english, claw
# 0.000s, ALREADY EXISTS, row29, zh, 鱼
# 0.000s, ALREADY EXISTS, row29, english, fish
# 0.000s, ALREADY EXISTS, row30, zh, 长颈鹿
# 0.000s, ALREADY EXISTS, row30, zh_slow, 长颈鹿
# 0.000s, ALREADY EXISTS, row30, english, giraffe
# 0.000s, ALREADY EXISTS, row30, zh, 长
# 0.000s, ALREADY EXISTS, row30, zh, 颈部
# 0.000s, ALREADY EXISTS, row30, english, long
# 0.000s, ALREADY EXISTS, row30, english, neck
# 0.000s, ALREADY EXISTS, row30, zh, 鹿
# 0.000s, ALREADY EXISTS, row30, english, deer
# 0.000s, ALREADY EXISTS, row31, zh, 飞虫
# 0.000s, ALREADY EXISTS, row31, zh_slow, 飞虫
# 0.000s, ALREADY EXISTS, row31, english, fly;flying insect
# 0.000s, ALREADY EXISTS, row31, zh, 飞
# 0.000s, ALREADY EXISTS, row31, zh, 虫子
# 0.000s, ALREADY EXISTS, row31, english, to fly
# 0.000s, ALREADY EXISTS, row31, english, bug
# 0.000s, ALREADY EXISTS, row32, zh, 抚摸
# 0.000s, ALREADY EXISTS, row32, zh_slow, 抚摸
# 0.000s, ALREADY EXISTS, row32, english, to pet;caress
# 0.000s, ALREADY EXISTS, row32, zh, 抚慰
# 0.000s, ALREADY EXISTS, row32, zh, 摸
# 0.000s, ALREADY EXISTS, row32, english, to soothe
# 0.000s, ALREADY EXISTS, row32, english, to touch (with hand)
# 0.000s, ALREADY EXISTS, row33, zh, 黄牛
# 0.000s, ALREADY EXISTS, row33, zh_slow, 黄牛
# 0.000s, ALREADY EXISTS, row33, english, cattle;scalper
# 0.000s, ALREADY EXISTS, row33, zh, 黄
# 0.000s, ALREADY EXISTS, row33, zh, 牛
# 0.000s, ALREADY EXISTS, row33, english, yellow
# 0.000s, ALREADY EXISTS, row33, english, cow
# 0.000s, ALREADY EXISTS, row34, zh, 郊狼
# 0.000s, ALREADY EXISTS, row34, zh_slow, 郊狼
# 0.000s, ALREADY EXISTS, row34, english, coyote
# 0.000s, ALREADY EXISTS, row34, zh, 郊区
# 0.000s, ALREADY EXISTS, row34, zh, 狼
# 0.000s, ALREADY EXISTS, row34, english, suburb
# 0.000s, ALREADY EXISTS, row34, english, wolf
# 0.000s, ALREADY EXISTS, row35, zh, 恐龙
# 0.000s, ALREADY EXISTS, row35, zh_slow, 恐龙
# 0.000s, ALREADY EXISTS, row35, english, dinosaur
# 0.000s, ALREADY EXISTS, row35, zh, 恐怕
# 0.000s, ALREADY EXISTS, row35, zh, 龙
# 0.000s, ALREADY EXISTS, row35, english, fear
# 0.000s, ALREADY EXISTS, row35, english, dragon
# 0.000s, ALREADY EXISTS, row36, zh, 龙虾
# 0.000s, ALREADY EXISTS, row36, zh_slow, 龙虾
# 0.000s, ALREADY EXISTS, row36, english, lobster
# 0.000s, ALREADY EXISTS, row36, zh, 龙
# 0.000s, ALREADY EXISTS, row36, zh, 虾
# 0.000s, ALREADY EXISTS, row36, english, dragon
# 0.000s, ALREADY EXISTS, row36, english, shrimp
# 0.000s, ALREADY EXISTS, row37, zh, 毛皮
# 0.000s, ALREADY EXISTS, row37, zh_slow, 毛皮
# 0.000s, ALREADY EXISTS, row37, english, fur
# 0.000s, ALREADY EXISTS, row37, zh, 毛
# 0.000s, ALREADY EXISTS, row37, zh, 皮
# 0.000s, ALREADY EXISTS, row37, english, hair
# 0.000s, ALREADY EXISTS, row37, english, skin
# 0.000s, ALREADY EXISTS, row38, zh, 山羊
# 0.000s, ALREADY EXISTS, row38, zh_slow, 山羊
# 0.000s, ALREADY EXISTS, row38, english, goat
# 0.000s, ALREADY EXISTS, row38, zh, 山
# 0.000s, ALREADY EXISTS, row38, zh, 羊
# 0.000s, ALREADY EXISTS, row38, english, mountain
# 0.000s, ALREADY EXISTS, row38, english, sheep
# 0.000s, ALREADY EXISTS, row39, zh, 汪汪
# 0.000s, ALREADY EXISTS, row39, zh_slow, 汪汪
# 0.000s, ALREADY EXISTS, row39, english, woof woof
# 0.000s, ALREADY EXISTS, row39, zh, 字
# 0.000s, ALREADY EXISTS, row39, zh, 身体
# 0.000s, ALREADY EXISTS, row39, english, character
# 0.000s, ALREADY EXISTS, row39, english, body
# 0.000s, ALREADY EXISTS, row40, zh, 项圈
# 0.000s, ALREADY EXISTS, row40, zh_slow, 项圈
# 0.000s, ALREADY EXISTS, row40, english, collar (for a dog)
# 0.000s, ALREADY EXISTS, row40, zh, 项
# 0.000s, ALREADY EXISTS, row40, zh, 圈
# 0.000s, ALREADY EXISTS, row40, english, neck
# 0.000s, ALREADY EXISTS, row40, english, circle
# 0.000s, ALREADY EXISTS, row41, zh, 博士
# 0.000s, ALREADY EXISTS, row41, zh_slow, 博士
# 0.000s, ALREADY EXISTS, row41, english, PhD
# 0.000s, ALREADY EXISTS, row41, zh, 博
# 0.000s, ALREADY EXISTS, row41, zh, 士
# 0.000s, ALREADY EXISTS, row41, english, plentiful
# 0.000s, ALREADY EXISTS, row41, english, scholar
# 0.000s, ALREADY EXISTS, row42, zh, 博士生导师
# 0.000s, ALREADY EXISTS, row42, zh_slow, 博士生导师
# 0.000s, ALREADY EXISTS, row42, english, doctoral supervisor
# 0.000s, ALREADY EXISTS, row42, zh, 博士
# 0.000s, ALREADY EXISTS, row42, zh, 学生
# 0.000s, ALREADY EXISTS, row42, english, PhD
# 0.000s, ALREADY EXISTS, row42, english, student
# 0.000s, ALREADY EXISTS, row42, zh, 导师
# 0.000s, ALREADY EXISTS, row42, english, supervisor
# 0.000s, ALREADY EXISTS, row43, zh, 创始人
# 0.000s, ALREADY EXISTS, row43, zh_slow, 创始人
# 0.000s, ALREADY EXISTS, row43, english, founder;creator
# 0.000s, ALREADY EXISTS, row43, zh, 创造
# 0.000s, ALREADY EXISTS, row43, zh, 开始
# 0.000s, ALREADY EXISTS, row43, english, to create
# 0.000s, ALREADY EXISTS, row43, english, to start
# 0.000s, ALREADY EXISTS, row43, zh, 人
# 0.000s, ALREADY EXISTS, row43, english, person
# 0.000s, ALREADY EXISTS, row44, zh, 创业
# 0.000s, ALREADY EXISTS, row44, zh_slow, 创业
# 0.000s, ALREADY EXISTS, row44, english, entrepreneurship;initiate
# 0.000s, ALREADY EXISTS, row44, zh, 创造
# 0.000s, ALREADY EXISTS, row44, zh, 企业
# 0.000s, ALREADY EXISTS, row44, english, to create
# 0.000s, ALREADY EXISTS, row44, english, company
# 0.000s, ALREADY EXISTS, row45, zh, 程序员
# 0.000s, ALREADY EXISTS, row45, zh_slow, 程序员
# 0.000s, ALREADY EXISTS, row45, english, programmer
# 0.000s, ALREADY EXISTS, row45, zh, 工程
# 0.000s, ALREADY EXISTS, row45, zh, 序
# 0.000s, ALREADY EXISTS, row45, english, engineering
# 0.000s, ALREADY EXISTS, row45, english, sequence
# 0.000s, ALREADY EXISTS, row45, zh, 员
# 0.000s, ALREADY EXISTS, row45, english, worker
# 0.000s, ALREADY EXISTS, row46, zh, 产假
# 0.000s, ALREADY EXISTS, row46, zh_slow, 产假
# 0.000s, ALREADY EXISTS, row46, english, maternity leave
# 0.000s, ALREADY EXISTS, row46, zh, 产
# 0.000s, ALREADY EXISTS, row46, zh, 假期
# 0.000s, ALREADY EXISTS, row46, english, to give birth;produce
# 0.000s, ALREADY EXISTS, row46, english, vacation
# 0.000s, ALREADY EXISTS, row47, zh, 裁员
# 0.000s, ALREADY EXISTS, row47, zh_slow, 裁员
# 0.000s, ALREADY EXISTS, row47, english, layoff
# 0.000s, ALREADY EXISTS, row47, zh, 裁
# 0.000s, ALREADY EXISTS, row47, zh, 员
# 0.000s, ALREADY EXISTS, row47, english, to cut out
# 0.000s, ALREADY EXISTS, row47, english, staff
# 0.000s, ALREADY EXISTS, row48, zh, 店长
# 0.000s, ALREADY EXISTS, row48, zh_slow, 店长
# 0.000s, ALREADY EXISTS, row48, english, store manager
# 0.000s, ALREADY EXISTS, row48, zh, 店
# 0.000s, ALREADY EXISTS, row48, zh, 长官
# 0.000s, ALREADY EXISTS, row48, english, store
# 0.000s, ALREADY EXISTS, row48, english, senior official
# 0.000s, ALREADY EXISTS, row49, zh, 队友
# 0.000s, ALREADY EXISTS, row49, zh_slow, 队友
# 0.000s, ALREADY EXISTS, row49, english, teammate
# 0.000s, ALREADY EXISTS, row49, zh, 队
# 0.000s, ALREADY EXISTS, row49, zh, 友
# 0.000s, ALREADY EXISTS, row49, english, team
# 0.000s, ALREADY EXISTS, row49, english, friend
# 0.000s, ALREADY EXISTS, row50, zh, 导师
# 0.000s, ALREADY EXISTS, row50, zh_slow, 导师
# 0.000s, ALREADY EXISTS, row50, english, tutor;supervisor
# 0.000s, ALREADY EXISTS, row50, zh, 领导
# 0.000s, ALREADY EXISTS, row50, zh, 老师
# 0.000s, ALREADY EXISTS, row50, english, leader
# 0.000s, ALREADY EXISTS, row50, english, teacher
# 0.000s, ALREADY EXISTS, row51, zh, 房地产
# 0.000s, ALREADY EXISTS, row51, zh_slow, 房地产
# 0.000s, ALREADY EXISTS, row51, english, real estate
# 0.000s, ALREADY EXISTS, row51, zh, 房
# 0.000s, ALREADY EXISTS, row51, zh, 地
# 0.000s, ALREADY EXISTS, row51, english, house
# 0.000s, ALREADY EXISTS, row51, english, land
# 0.000s, ALREADY EXISTS, row51, zh, 财产
# 0.000s, ALREADY EXISTS, row51, english, property
# 0.000s, ALREADY EXISTS, row52, zh, 发明
# 0.000s, ALREADY EXISTS, row52, zh_slow, 发明
# 0.000s, ALREADY EXISTS, row52, english, to invent;invention
# 0.000s, ALREADY EXISTS, row52, zh, 发现
# 0.000s, ALREADY EXISTS, row52, zh, 聪明
# 0.000s, ALREADY EXISTS, row52, english, to discover
# 0.000s, ALREADY EXISTS, row52, english, smart
# 0.000s, ALREADY EXISTS, row53, zh, 分公司
# 0.000s, ALREADY EXISTS, row53, zh_slow, 分公司
# 0.000s, ALREADY EXISTS, row53, english, branch (office)
# 0.000s, ALREADY EXISTS, row53, zh, 分
# 0.000s, ALREADY EXISTS, row53, zh, 公司
# 0.000s, ALREADY EXISTS, row53, english, part
# 0.000s, ALREADY EXISTS, row53, english, company
# 0.000s, ALREADY EXISTS, row54, zh, 高级
# 0.000s, ALREADY EXISTS, row54, zh_slow, 高级
# 0.000s, ALREADY EXISTS, row54, english, senior (engineer, manager, professional title)
# 0.000s, ALREADY EXISTS, row54, zh, 高
# 0.000s, ALREADY EXISTS, row54, zh, 级
# 0.000s, ALREADY EXISTS, row54, english, high
# 0.000s, ALREADY EXISTS, row54, english, level
# 0.000s, ALREADY EXISTS, row55, zh, 工程
# 0.000s, ALREADY EXISTS, row55, zh_slow, 工程
# 0.000s, ALREADY EXISTS, row55, english, engineering;project
# 0.000s, ALREADY EXISTS, row55, zh, 工
# 0.000s, ALREADY EXISTS, row55, zh, 过程
# 0.000s, ALREADY EXISTS, row55, english, work
# 0.000s, ALREADY EXISTS, row55, english, process
# 0.000s, ALREADY EXISTS, row56, zh, 股票
# 0.000s, ALREADY EXISTS, row56, zh_slow, 股票
# 0.000s, ALREADY EXISTS, row56, english, stock
# 0.000s, ALREADY EXISTS, row56, zh, 屁股
# 0.000s, ALREADY EXISTS, row56, zh, 票
# 0.000s, ALREADY EXISTS, row56, english, butt
# 0.000s, ALREADY EXISTS, row56, english, ticket
# 0.000s, ALREADY EXISTS, row57, zh, 股市
# 0.000s, ALREADY EXISTS, row57, zh_slow, 股市
# 0.000s, ALREADY EXISTS, row57, english, stock market
# 0.000s, ALREADY EXISTS, row57, zh, 股票
# 0.000s, ALREADY EXISTS, row57, zh, 市
# 0.000s, ALREADY EXISTS, row57, english, stock
# 0.000s, ALREADY EXISTS, row57, english, market
# 0.000s, ALREADY EXISTS, row58, zh, 化学
# 0.000s, ALREADY EXISTS, row58, zh_slow, 化学
# 0.000s, ALREADY EXISTS, row58, english, chemistry
# 0.000s, ALREADY EXISTS, row58, zh, 变化
# 0.000s, ALREADY EXISTS, row58, zh, 学
# 0.000s, ALREADY EXISTS, row58, english, to change
# 0.000s, ALREADY EXISTS, row58, english, study
# 0.000s, ALREADY EXISTS, row59, zh, 会议室
# 0.000s, ALREADY EXISTS, row59, zh_slow, 会议室
# 0.000s, ALREADY EXISTS, row59, english, meeting room
# 0.000s, ALREADY EXISTS, row59, zh, 会议
# 0.000s, ALREADY EXISTS, row59, zh, 室
# 0.000s, ALREADY EXISTS, row59, english, meeting
# 0.000s, ALREADY EXISTS, row59, english, room
# 0.000s, ALREADY EXISTS, row60, zh, 解雇
# 0.000s, ALREADY EXISTS, row60, zh_slow, 解雇
# 0.000s, ALREADY EXISTS, row60, english, to fire;terminate
# 0.000s, ALREADY EXISTS, row60, zh, 解决
# 0.000s, ALREADY EXISTS, row60, zh, 雇佣
# 0.000s, ALREADY EXISTS, row60, english, to resolve
# 0.000s, ALREADY EXISTS, row60, english, to employ
# 0.000s, ALREADY EXISTS, row61, zh, 简历
# 0.000s, ALREADY EXISTS, row61, zh_slow, 简历
# 0.000s, ALREADY EXISTS, row61, english, résumé;cv
# 0.000s, ALREADY EXISTS, row61, zh, 简
# 0.000s, ALREADY EXISTS, row61, zh, 历
# 0.000s, ALREADY EXISTS, row61, english, simple
# 0.000s, ALREADY EXISTS, row61, english, history
# 0.000s, ALREADY EXISTS, row62, zh, 奖学金
# 0.000s, ALREADY EXISTS, row62, zh_slow, 奖学金
# 0.000s, ALREADY EXISTS, row62, english, scholarship
# 0.000s, ALREADY EXISTS, row62, zh, 奖
# 0.000s, ALREADY EXISTS, row62, zh, 学
# 0.000s, ALREADY EXISTS, row62, english, prize
# 0.000s, ALREADY EXISTS, row62, english, learning
# 0.000s, ALREADY EXISTS, row62, zh, 资金
# 0.000s, ALREADY EXISTS, row62, english, funds
# 0.000s, ALREADY EXISTS, row63, zh, 技术
# 0.000s, ALREADY EXISTS, row63, zh_slow, 技术
# 0.000s, ALREADY EXISTS, row63, english, technology
# 0.000s, ALREADY EXISTS, row63, zh, 技
# 0.000s, ALREADY EXISTS, row63, zh, 术
# 0.000s, ALREADY EXISTS, row63, english, skill
# 0.000s, ALREADY EXISTS, row63, english, art
# 0.000s, ALREADY EXISTS, row64, zh, 进口
# 0.000s, ALREADY EXISTS, row64, zh_slow, 进口
# 0.000s, ALREADY EXISTS, row64, english, import
# 0.000s, ALREADY EXISTS, row64, zh, 进
# 0.000s, ALREADY EXISTS, row64, zh, 口
# 0.000s, ALREADY EXISTS, row64, english, enter
# 0.000s, ALREADY EXISTS, row64, english, opening
# 0.000s, ALREADY EXISTS, row65, zh, 机会
# 0.000s, ALREADY EXISTS, row65, zh_slow, 机会
# 0.000s, ALREADY EXISTS, row65, english, opportunity;chance
# 0.000s, ALREADY EXISTS, row65, zh, 机
# 0.000s, ALREADY EXISTS, row65, zh, 会
# 0.000s, ALREADY EXISTS, row65, english, machine
# 0.000s, ALREADY EXISTS, row65, english, to be able to
# 0.000s, ALREADY EXISTS, row66, zh, 金融
# 0.000s, ALREADY EXISTS, row66, zh_slow, 金融
# 0.000s, ALREADY EXISTS, row66, english, finance;banking
# 0.000s, ALREADY EXISTS, row66, zh, 金
# 0.000s, ALREADY EXISTS, row66, zh, 融化
# 0.000s, ALREADY EXISTS, row66, english, metal
# 0.000s, ALREADY EXISTS, row66, english, to melt
# 0.000s, ALREADY EXISTS, row67, zh, 经纪人
# 0.000s, ALREADY EXISTS, row67, zh_slow, 经纪人
# 0.000s, ALREADY EXISTS, row67, english, agent;broker;middleman
# 4.169s, row67, zh, 经纪
# 0.000s, ALREADY EXISTS, row67, zh, 人
# 0.000s, ALREADY EXISTS, row67, english, manager
# 0.000s, ALREADY EXISTS, row67, english, person
# 0.000s, ALREADY EXISTS, row68, zh, 经理
# 0.000s, ALREADY EXISTS, row68, zh_slow, 经理
# 0.000s, ALREADY EXISTS, row68, english, manager
# 0.000s, ALREADY EXISTS, row68, zh, 经济
# 0.000s, ALREADY EXISTS, row68, zh, 管理
# 0.000s, ALREADY EXISTS, row68, english, economy
# 0.000s, ALREADY EXISTS, row68, english, to manage
# 0.000s, ALREADY EXISTS, row69, zh, 科目
# 0.000s, ALREADY EXISTS, row69, zh_slow, 科目
# 0.000s, ALREADY EXISTS, row69, english, subject (school)
# 0.000s, ALREADY EXISTS, row69, zh, 科学
# 0.000s, ALREADY EXISTS, row69, zh, 节目
# 0.000s, ALREADY EXISTS, row69, english, science
# 0.000s, ALREADY EXISTS, row69, english, program
# 0.000s, ALREADY EXISTS, row70, zh, 老板
# 0.000s, ALREADY EXISTS, row70, zh_slow, 老板
# 0.000s, ALREADY EXISTS, row70, english, boss
# 0.000s, ALREADY EXISTS, row70, zh, 老
# 0.000s, ALREADY EXISTS, row70, zh, 板
# 0.000s, ALREADY EXISTS, row70, english, old
# 0.000s, ALREADY EXISTS, row70, english, plank;board
# 0.000s, ALREADY EXISTS, row71, zh, 理论
# 0.000s, ALREADY EXISTS, row71, zh_slow, 理论
# 0.000s, ALREADY EXISTS, row71, english, theory
# 0.000s, ALREADY EXISTS, row71, zh, 理由
# 0.000s, ALREADY EXISTS, row71, zh, 讨论
# 0.000s, ALREADY EXISTS, row71, english, reason;justification
# 0.000s, ALREADY EXISTS, row71, english, to discuss
# 0.000s, ALREADY EXISTS, row72, zh, 领域
# 0.000s, ALREADY EXISTS, row72, zh_slow, 领域
# 0.000s, ALREADY EXISTS, row72, english, domain;field
# 0.000s, ALREADY EXISTS, row72, zh, 领导
# 0.000s, ALREADY EXISTS, row72, zh, 区域
# 0.000s, ALREADY EXISTS, row72, english, to lead
# 0.000s, ALREADY EXISTS, row72, english, area
# 0.000s, ALREADY EXISTS, row73, zh, 面试
# 0.000s, ALREADY EXISTS, row73, zh_slow, 面试
# 0.000s, ALREADY EXISTS, row73, english, interview (job)
# 0.000s, ALREADY EXISTS, row73, zh, 面
# 0.000s, ALREADY EXISTS, row73, zh, 试
# 0.000s, ALREADY EXISTS, row73, english, face
# 0.000s, ALREADY EXISTS, row73, english, test
# 0.000s, ALREADY EXISTS, row74, zh, 目标
# 0.000s, ALREADY EXISTS, row74, zh_slow, 目标
# 0.000s, ALREADY EXISTS, row74, english, goal;target;objective
# 0.000s, ALREADY EXISTS, row74, zh, 目
# 0.000s, ALREADY EXISTS, row74, zh, 标志
# 0.000s, ALREADY EXISTS, row74, english, eye
# 0.000s, ALREADY EXISTS, row74, english, sign
# 0.000s, ALREADY EXISTS, row75, zh, 脑科学
# 0.000s, ALREADY EXISTS, row75, zh_slow, 脑科学
# 0.000s, ALREADY EXISTS, row75, english, neuroscience;brain science
# 0.000s, ALREADY EXISTS, row75, zh, 脑
# 0.000s, ALREADY EXISTS, row75, zh, 科学
# 0.000s, ALREADY EXISTS, row75, english, brain
# 0.000s, ALREADY EXISTS, row75, english, science
# 0.000s, ALREADY EXISTS, row76, zh, 全职
# 0.000s, ALREADY EXISTS, row76, zh_slow, 全职
# 0.000s, ALREADY EXISTS, row76, english, full time
# 0.000s, ALREADY EXISTS, row76, zh, 全
# 0.000s, ALREADY EXISTS, row76, zh, 职业
# 0.000s, ALREADY EXISTS, row76, english, entire
# 0.000s, ALREADY EXISTS, row76, english, profession
# 0.000s, ALREADY EXISTS, row77, zh, 骑手
# 0.000s, ALREADY EXISTS, row77, zh_slow, 骑手
# 0.000s, ALREADY EXISTS, row77, english, rider;delivery person
# 0.000s, ALREADY EXISTS, row77, zh, 骑
# 0.000s, ALREADY EXISTS, row77, zh, 手
# 0.000s, ALREADY EXISTS, row77, english, ride
# 0.000s, ALREADY EXISTS, row77, english, hand
# 0.000s, ALREADY EXISTS, row78, zh, 实验
# 0.000s, ALREADY EXISTS, row78, zh_slow, 实验
# 0.000s, ALREADY EXISTS, row78, english, experiment
# 0.000s, ALREADY EXISTS, row78, zh, 事实
# 0.000s, ALREADY EXISTS, row78, zh, 经验
# 0.000s, ALREADY EXISTS, row78, english, fact
# 0.000s, ALREADY EXISTS, row78, english, experience
# 0.000s, ALREADY EXISTS, row79, zh, 生产
# 0.000s, ALREADY EXISTS, row79, zh_slow, 生产
# 0.000s, ALREADY EXISTS, row79, english, to produce;production
# 0.000s, ALREADY EXISTS, row79, zh, 发生
# 0.000s, ALREADY EXISTS, row79, zh, 产品
# 0.000s, ALREADY EXISTS, row79, english, to happen
# 0.000s, ALREADY EXISTS, row79, english, goods
# 0.000s, ALREADY EXISTS, row80, zh, 升职
# 0.000s, ALREADY EXISTS, row80, zh_slow, 升职
# 0.000s, ALREADY EXISTS, row80, english, to get promoted;promotion
# 0.000s, ALREADY EXISTS, row80, zh, 升
# 0.000s, ALREADY EXISTS, row80, zh, 职业
# 0.000s, ALREADY EXISTS, row80, english, to rise
# 0.000s, ALREADY EXISTS, row80, english, occupation
# 0.000s, ALREADY EXISTS, row81, zh, 失业
# 0.000s, ALREADY EXISTS, row81, zh_slow, 失业
# 0.000s, ALREADY EXISTS, row81, english, unemployment;to lose one's job
# 0.000s, ALREADY EXISTS, row81, zh, 失
# 0.000s, ALREADY EXISTS, row81, zh, 职业
# 0.000s, ALREADY EXISTS, row81, english, lose
# 0.000s, ALREADY EXISTS, row81, english, profession
# 0.000s, ALREADY EXISTS, row82, zh, 收入
# 0.000s, ALREADY EXISTS, row82, zh_slow, 收入
# 0.000s, ALREADY EXISTS, row82, english, income
# 0.000s, ALREADY EXISTS, row82, zh, 收
# 0.000s, ALREADY EXISTS, row82, zh, 入
# 0.000s, ALREADY EXISTS, row82, english, to receive
# 0.000s, ALREADY EXISTS, row82, english, to enter
# 0.000s, ALREADY EXISTS, row83, zh, 天文
# 0.000s, ALREADY EXISTS, row83, zh_slow, 天文
# 0.000s, ALREADY EXISTS, row83, english, astronomy
# 0.000s, ALREADY EXISTS, row83, zh, 天
# 0.000s, ALREADY EXISTS, row83, zh, 文
# 0.000s, ALREADY EXISTS, row83, english, sky
# 0.000s, ALREADY EXISTS, row83, english, arts
# 0.000s, ALREADY EXISTS, row84, zh, 退出
# 0.000s, ALREADY EXISTS, row84, zh_slow, 退出
# 0.000s, ALREADY EXISTS, row84, english, quit
# 0.000s, ALREADY EXISTS, row84, zh, 退
# 0.000s, ALREADY EXISTS, row84, zh, 出
# 0.000s, ALREADY EXISTS, row84, english, to retreat
# 0.000s, ALREADY EXISTS, row84, english, to go out
# 0.000s, ALREADY EXISTS, row85, zh, 退休
# 0.000s, ALREADY EXISTS, row85, zh_slow, 退休
# 0.000s, ALREADY EXISTS, row85, english, to retire
# 0.000s, ALREADY EXISTS, row85, zh, 退
# 0.000s, ALREADY EXISTS, row85, zh, 休
# 0.000s, ALREADY EXISTS, row85, english, to retreat
# 0.000s, ALREADY EXISTS, row85, english, to rest
# 0.000s, ALREADY EXISTS, row86, zh, 谈判
# 0.000s, ALREADY EXISTS, row86, zh_slow, 谈判
# 0.000s, ALREADY EXISTS, row86, english, to negotiate
# 0.000s, ALREADY EXISTS, row86, zh, 谈
# 0.000s, ALREADY EXISTS, row86, zh, 批判
# 0.000s, ALREADY EXISTS, row86, english, talk
# 0.000s, ALREADY EXISTS, row86, english, to criticize
# 0.000s, ALREADY EXISTS, row87, zh, 同事
# 0.000s, ALREADY EXISTS, row87, zh_slow, 同事
# 0.000s, ALREADY EXISTS, row87, english, colleague;coworker
# 0.000s, ALREADY EXISTS, row87, zh, 同
# 0.000s, ALREADY EXISTS, row87, zh, 事
# 0.000s, ALREADY EXISTS, row87, english, same
# 0.000s, ALREADY EXISTS, row87, english, matter
# 0.000s, ALREADY EXISTS, row88, zh, 投入
# 0.000s, ALREADY EXISTS, row88, zh_slow, 投入
# 0.000s, ALREADY EXISTS, row88, english, invest in;to throw into
# 0.000s, ALREADY EXISTS, row88, zh, 投
# 0.000s, ALREADY EXISTS, row88, zh, 入
# 0.000s, ALREADY EXISTS, row88, english, to throw
# 0.000s, ALREADY EXISTS, row88, english, to enter
# 0.000s, ALREADY EXISTS, row89, zh, 投资
# 0.000s, ALREADY EXISTS, row89, zh_slow, 投资
# 0.000s, ALREADY EXISTS, row89, english, invest
# 0.000s, ALREADY EXISTS, row89, zh, 投票
# 0.000s, ALREADY EXISTS, row89, zh, 资源
# 0.000s, ALREADY EXISTS, row89, english, to vote
# 0.000s, ALREADY EXISTS, row89, english, resource
# 0.000s, ALREADY EXISTS, row90, zh, 图表
# 0.000s, ALREADY EXISTS, row90, zh_slow, 图表
# 0.000s, ALREADY EXISTS, row90, english, chart;graph
# 0.000s, ALREADY EXISTS, row90, zh, 图
# 0.000s, ALREADY EXISTS, row90, zh, 表格
# 0.000s, ALREADY EXISTS, row90, english, picture
# 0.000s, ALREADY EXISTS, row90, english, sheet;table
# 0.000s, ALREADY EXISTS, row91, zh, 统计
# 0.000s, ALREADY EXISTS, row91, zh_slow, 统计
# 0.000s, ALREADY EXISTS, row91, english, statistics
# 0.000s, ALREADY EXISTS, row91, zh, 系统
# 0.000s, ALREADY EXISTS, row91, zh, 估计
# 0.000s, ALREADY EXISTS, row91, english, system
# 0.000s, ALREADY EXISTS, row91, english, to estimate
# 0.000s, ALREADY EXISTS, row92, zh, 外贸
# 0.000s, ALREADY EXISTS, row92, zh_slow, 外贸
# 0.000s, ALREADY EXISTS, row92, english, foreign trade
# 0.000s, ALREADY EXISTS, row92, zh, 外
# 0.000s, ALREADY EXISTS, row92, zh, 贸易
# 0.000s, ALREADY EXISTS, row92, english, outside
# 0.000s, ALREADY EXISTS, row92, english, trade
# 0.000s, ALREADY EXISTS, row93, zh, 文件
# 0.000s, ALREADY EXISTS, row93, zh_slow, 文件
# 0.000s, ALREADY EXISTS, row93, english, document;file
# 0.000s, ALREADY EXISTS, row93, zh, 文
# 0.000s, ALREADY EXISTS, row93, zh, 件
# 0.000s, ALREADY EXISTS, row93, english, writing
# 0.000s, ALREADY EXISTS, row93, english, piece
# 0.000s, ALREADY EXISTS, row94, zh, 物流
# 0.000s, ALREADY EXISTS, row94, zh_slow, 物流
# 0.000s, ALREADY EXISTS, row94, english, logistics
# 0.000s, ALREADY EXISTS, row94, zh, 物
# 0.000s, ALREADY EXISTS, row94, zh, 流
# 0.000s, ALREADY EXISTS, row94, english, thing
# 0.000s, ALREADY EXISTS, row94, english, flow
# 0.000s, ALREADY EXISTS, row95, zh, 物理
# 0.000s, ALREADY EXISTS, row95, zh_slow, 物理
# 0.000s, ALREADY EXISTS, row95, english, physics
# 0.000s, ALREADY EXISTS, row95, zh, 物
# 0.000s, ALREADY EXISTS, row95, zh, 理论
# 0.000s, ALREADY EXISTS, row95, english, thing
# 0.000s, ALREADY EXISTS, row95, english, theory
# 0.000s, ALREADY EXISTS, row96, zh, 校区
# 0.000s, ALREADY EXISTS, row96, zh_slow, 校区
# 0.000s, ALREADY EXISTS, row96, english, campus
# 0.000s, ALREADY EXISTS, row96, zh, 学校
# 0.000s, ALREADY EXISTS, row96, zh, 区
# 0.000s, ALREADY EXISTS, row96, english, school
# 0.000s, ALREADY EXISTS, row96, english, district
# 0.000s, ALREADY EXISTS, row97, zh, 校园
# 0.000s, ALREADY EXISTS, row97, zh_slow, 校园
# 0.000s, ALREADY EXISTS, row97, english, campus
# 0.000s, ALREADY EXISTS, row97, zh, 学校
# 0.000s, ALREADY EXISTS, row97, zh, 公园
# 0.000s, ALREADY EXISTS, row97, english, school
# 0.000s, ALREADY EXISTS, row97, english, park
# 0.000s, ALREADY EXISTS, row98, zh, 学期
# 0.000s, ALREADY EXISTS, row98, zh_slow, 学期
# 0.000s, ALREADY EXISTS, row98, english, semester;term
# 0.000s, ALREADY EXISTS, row98, zh, 学
# 0.000s, ALREADY EXISTS, row98, zh, 期
# 0.000s, ALREADY EXISTS, row98, english, to study
# 0.000s, ALREADY EXISTS, row98, english, period of time
# 0.000s, ALREADY EXISTS, row99, zh, 学术界
# 0.000s, ALREADY EXISTS, row99, zh_slow, 学术界
# 0.000s, ALREADY EXISTS, row99, english, academia
# 0.000s, ALREADY EXISTS, row99, zh, 学
# 0.000s, ALREADY EXISTS, row99, zh, 术
# 0.000s, ALREADY EXISTS, row99, english, to study
# 0.000s, ALREADY EXISTS, row99, english, art
# 0.000s, ALREADY EXISTS, row99, zh, 世界
# 0.000s, ALREADY EXISTS, row99, english, world
# 0.000s, ALREADY EXISTS, row100, zh, 远程
# 0.000s, ALREADY EXISTS, row100, zh_slow, 远程
# 0.000s, ALREADY EXISTS, row100, english, remote (work)
# 0.000s, ALREADY EXISTS, row100, zh, 远
# 0.000s, ALREADY EXISTS, row100, zh, 程度
# 0.000s, ALREADY EXISTS, row100, english, far
# 0.000s, ALREADY EXISTS, row100, english, degree;extent
# 0.000s, ALREADY EXISTS, row101, zh, 研一
# 0.000s, ALREADY EXISTS, row101, zh_slow, 研一
# 0.000s, ALREADY EXISTS, row101, english, first year graduate student
# 0.000s, ALREADY EXISTS, row101, zh, 研究生
# 0.000s, ALREADY EXISTS, row101, zh, 一
# 0.000s, ALREADY EXISTS, row101, english, graduate student
# 0.000s, ALREADY EXISTS, row101, english, one
# 0.000s, ALREADY EXISTS, row102, zh, 演讲
# 0.000s, ALREADY EXISTS, row102, zh_slow, 演讲
# 0.000s, ALREADY EXISTS, row102, english, lecture;speech
# 0.000s, ALREADY EXISTS, row102, zh, 演
# 0.000s, ALREADY EXISTS, row102, zh, 讲
# 0.000s, ALREADY EXISTS, row102, english, perform
# 0.000s, ALREADY EXISTS, row102, english, to speak
# 0.000s, ALREADY EXISTS, row103, zh, 专业
# 0.000s, ALREADY EXISTS, row103, zh_slow, 专业
# 0.000s, ALREADY EXISTS, row103, english, major;professional (quality);specialty
# 0.000s, ALREADY EXISTS, row103, zh, 专家
# 0.000s, ALREADY EXISTS, row103, zh, 行业
# 0.000s, ALREADY EXISTS, row103, english, expert
# 0.000s, ALREADY EXISTS, row103, english, industry
# 0.000s, ALREADY EXISTS, row104, zh, 志愿者
# 0.000s, ALREADY EXISTS, row104, zh_slow, 志愿者
# 0.000s, ALREADY EXISTS, row104, english, volunteer
# 0.000s, ALREADY EXISTS, row104, zh, 志
# 0.000s, ALREADY EXISTS, row104, zh, 愿
# 0.000s, ALREADY EXISTS, row104, english, purpose
# 0.000s, ALREADY EXISTS, row104, english, sincere
# 0.000s, ALREADY EXISTS, row104, zh, 者
# 0.000s, ALREADY EXISTS, row104, english, one who
# 0.000s, ALREADY EXISTS, row105, zh, 高级
# 0.000s, ALREADY EXISTS, row105, zh_slow, 高级
# 0.000s, ALREADY EXISTS, row105, english, advanced
# 0.000s, ALREADY EXISTS, row105, zh, 高
# 0.000s, ALREADY EXISTS, row105, zh, 级
# 0.000s, ALREADY EXISTS, row105, english, high
# 0.000s, ALREADY EXISTS, row105, english, level
# 0.000s, ALREADY EXISTS, row106, zh, 降低
# 0.000s, ALREADY EXISTS, row106, zh_slow, 降低
# 0.000s, ALREADY EXISTS, row106, english, to lower;reduce
# 0.000s, ALREADY EXISTS, row106, zh, 降
# 0.000s, ALREADY EXISTS, row106, zh, 低
# 0.000s, ALREADY EXISTS, row106, english, to drop
# 0.000s, ALREADY EXISTS, row106, english, low
# 0.000s, ALREADY EXISTS, row107, zh, 上一个
# 0.000s, ALREADY EXISTS, row107, zh_slow, 上一个
# 0.000s, ALREADY EXISTS, row107, english, previous
# 0.000s, ALREADY EXISTS, row107, zh, 上
# 0.000s, ALREADY EXISTS, row107, zh, 一个
# 0.000s, ALREADY EXISTS, row107, english, upper
# 0.000s, ALREADY EXISTS, row107, english, one
# 0.000s, ALREADY EXISTS, row108, zh, 提高
# 0.000s, ALREADY EXISTS, row108, zh_slow, 提高
# 0.000s, ALREADY EXISTS, row108, english, to raise;increase;improve
# 0.000s, ALREADY EXISTS, row108, zh, 提
# 0.000s, ALREADY EXISTS, row108, zh, 高
# 0.000s, ALREADY EXISTS, row108, english, to lift
# 0.000s, ALREADY EXISTS, row108, english, high
# 0.000s, ALREADY EXISTS, row109, zh, 变态
# 0.000s, ALREADY EXISTS, row109, zh_slow, 变态
# 0.000s, ALREADY EXISTS, row109, english, abnormal;pervert
# 0.000s, ALREADY EXISTS, row109, zh, 变
# 0.000s, ALREADY EXISTS, row109, zh, 态度
# 0.000s, ALREADY EXISTS, row109, english, change
# 0.000s, ALREADY EXISTS, row109, english, manner
# 0.000s, ALREADY EXISTS, row110, zh, 不礼貌
# 0.000s, ALREADY EXISTS, row110, zh_slow, 不礼貌
# 0.000s, ALREADY EXISTS, row110, english, rude
# 0.000s, ALREADY EXISTS, row110, zh, 不
# 0.000s, ALREADY EXISTS, row110, zh, 礼貌
# 0.000s, ALREADY EXISTS, row110, english, no
# 0.000s, ALREADY EXISTS, row110, english, manners
# 0.000s, ALREADY EXISTS, row111, zh, 创意
# 0.000s, ALREADY EXISTS, row111, zh_slow, 创意
# 0.000s, ALREADY EXISTS, row111, english, creativity;creative
# 0.000s, ALREADY EXISTS, row111, zh, 创造
# 0.000s, ALREADY EXISTS, row111, zh, 意
# 0.000s, ALREADY EXISTS, row111, english, to create
# 0.000s, ALREADY EXISTS, row111, english, idea
# 0.000s, ALREADY EXISTS, row112, zh, 抽象
# 0.000s, ALREADY EXISTS, row112, zh_slow, 抽象
# 0.000s, ALREADY EXISTS, row112, english, abstract
# 0.000s, ALREADY EXISTS, row112, zh, 抽烟
# 0.000s, ALREADY EXISTS, row112, zh, 象
# 0.000s, ALREADY EXISTS, row112, english, to smoke
# 0.000s, ALREADY EXISTS, row112, english, elephant
# 0.000s, ALREADY EXISTS, row113, zh, 出色
# 0.000s, ALREADY EXISTS, row113, zh_slow, 出色
# 0.000s, ALREADY EXISTS, row113, english, remarkable;outstanding
# 0.000s, ALREADY EXISTS, row113, zh, 出
# 0.000s, ALREADY EXISTS, row113, zh, 色
# 0.000s, ALREADY EXISTS, row113, english, to go out
# 0.000s, ALREADY EXISTS, row113, english, color
# 0.000s, ALREADY EXISTS, row114, zh, 初学者
# 0.000s, ALREADY EXISTS, row114, zh_slow, 初学者
# 0.000s, ALREADY EXISTS, row114, english, beginner
# 0.000s, ALREADY EXISTS, row114, zh, 初
# 0.000s, ALREADY EXISTS, row114, zh, 学
# 0.000s, ALREADY EXISTS, row114, english, beginning
# 0.000s, ALREADY EXISTS, row114, english, study
# 0.000s, ALREADY EXISTS, row114, zh, 者
# 0.000s, ALREADY EXISTS, row114, english, one who
# 0.000s, ALREADY EXISTS, row115, zh, 才能
# 0.000s, ALREADY EXISTS, row115, zh_slow, 才能
# 0.000s, ALREADY EXISTS, row115, english, talent
# 0.000s, ALREADY EXISTS, row115, zh, 才
# 0.000s, ALREADY EXISTS, row115, zh, 能
# 0.000s, ALREADY EXISTS, row115, english, just
# 0.000s, ALREADY EXISTS, row115, english, can
# 0.000s, ALREADY EXISTS, row116, zh, 得体
# 0.000s, ALREADY EXISTS, row116, zh_slow, 得体
# 0.000s, ALREADY EXISTS, row116, english, appropriate
# 0.000s, ALREADY EXISTS, row116, zh, 得
# 0.000s, ALREADY EXISTS, row116, zh, 具体
# 0.000s, ALREADY EXISTS, row116, english, to get
# 0.000s, ALREADY EXISTS, row116, english, specific
# 0.000s, ALREADY EXISTS, row117, zh, 地道
# 0.000s, ALREADY EXISTS, row117, zh_slow, 地道
# 0.000s, ALREADY EXISTS, row117, english, typical;authentic
# 0.000s, ALREADY EXISTS, row117, zh, 当地
# 0.000s, ALREADY EXISTS, row117, zh, 道
# 0.000s, ALREADY EXISTS, row117, english, local
# 0.000s, ALREADY EXISTS, row117, english, road
# 0.000s, ALREADY EXISTS, row118, zh, 独立
# 0.000s, ALREADY EXISTS, row118, zh_slow, 独立
# 0.000s, ALREADY EXISTS, row118, english, independent
# 0.000s, ALREADY EXISTS, row118, zh, 单独
# 0.000s, ALREADY EXISTS, row118, zh, 立
# 0.000s, ALREADY EXISTS, row118, english, alone
# 0.000s, ALREADY EXISTS, row118, english, to stand
# 0.000s, ALREADY EXISTS, row119, zh, 独特
# 0.000s, ALREADY EXISTS, row119, zh_slow, 独特
# 0.000s, ALREADY EXISTS, row119, english, unique;distinct
# 0.000s, ALREADY EXISTS, row119, zh, 独立
# 0.000s, ALREADY EXISTS, row119, zh, 特别
# 0.000s, ALREADY EXISTS, row119, english, independent
# 0.000s, ALREADY EXISTS, row119, english, special
# 0.000s, ALREADY EXISTS, row120, zh, 低调
# 0.000s, ALREADY EXISTS, row120, zh_slow, 低调
# 0.000s, ALREADY EXISTS, row120, english, low key
# 0.000s, ALREADY EXISTS, row120, zh, 低
# 0.000s, ALREADY EXISTS, row120, zh, 调
# 0.000s, ALREADY EXISTS, row120, english, low
# 0.000s, ALREADY EXISTS, row120, english, tune
# 0.000s, ALREADY EXISTS, row121, zh, 负面
# 0.000s, ALREADY EXISTS, row121, zh_slow, 负面
# 0.000s, ALREADY EXISTS, row121, english, negative
# 0.000s, ALREADY EXISTS, row121, zh, 负担
# 0.000s, ALREADY EXISTS, row121, zh, 方面
# 0.000s, ALREADY EXISTS, row121, english, burden
# 0.000s, ALREADY EXISTS, row121, english, aspect
# 0.000s, ALREADY EXISTS, row122, zh, 复杂
# 0.000s, ALREADY EXISTS, row122, zh_slow, 复杂
# 0.000s, ALREADY EXISTS, row122, english, complicated;complex
# 0.000s, ALREADY EXISTS, row122, zh, 回复
# 0.000s, ALREADY EXISTS, row122, zh, 杂
# 0.000s, ALREADY EXISTS, row122, english, to reply
# 0.000s, ALREADY EXISTS, row122, english, mixed
# 0.000s, ALREADY EXISTS, row123, zh, 个人主义
# 0.000s, ALREADY EXISTS, row123, zh_slow, 个人主义
# 0.000s, ALREADY EXISTS, row123, english, individualism
# 0.000s, ALREADY EXISTS, row123, zh, 个人
# 0.000s, ALREADY EXISTS, row123, zh, 主义
# 0.000s, ALREADY EXISTS, row123, english, individual
# 0.000s, ALREADY EXISTS, row123, english, ideology
# 0.000s, ALREADY EXISTS, row124, zh, 固执
# 0.000s, ALREADY EXISTS, row124, zh_slow, 固执
# 0.000s, ALREADY EXISTS, row124, english, stubborn
# 0.000s, ALREADY EXISTS, row124, zh, 固定
# 0.000s, ALREADY EXISTS, row124, zh, 执行
# 0.000s, ALREADY EXISTS, row124, english, fixed
# 0.000s, ALREADY EXISTS, row124, english, to implement
# 0.000s, ALREADY EXISTS, row125, zh, 高手
# 0.000s, ALREADY EXISTS, row125, zh_slow, 高手
# 0.000s, ALREADY EXISTS, row125, english, master;expert
# 0.000s, ALREADY EXISTS, row125, zh, 高
# 0.000s, ALREADY EXISTS, row125, zh, 手
# 0.000s, ALREADY EXISTS, row125, english, high
# 0.000s, ALREADY EXISTS, row125, english, hand
# 0.000s, ALREADY EXISTS, row126, zh, 高效
# 0.000s, ALREADY EXISTS, row126, zh_slow, 高效
# 0.000s, ALREADY EXISTS, row126, english, efficient
# 0.000s, ALREADY EXISTS, row126, zh, 高
# 0.000s, ALREADY EXISTS, row126, zh, 效果
# 0.000s, ALREADY EXISTS, row126, english, high
# 0.000s, ALREADY EXISTS, row126, english, result
# 0.000s, ALREADY EXISTS, row127, zh, 坏处
# 0.000s, ALREADY EXISTS, row127, zh_slow, 坏处
# 0.000s, ALREADY EXISTS, row127, english, harm;trouble;disadvantage;con
# 0.000s, ALREADY EXISTS, row127, zh, 坏
# 0.000s, ALREADY EXISTS, row127, zh, 处理
# 0.000s, ALREADY EXISTS, row127, english, bad
# 0.000s, ALREADY EXISTS, row127, english, to handle
# 0.000s, ALREADY EXISTS, row128, zh, 害羞
# 0.000s, ALREADY EXISTS, row128, zh_slow, 害羞
# 0.000s, ALREADY EXISTS, row128, english, shy
# 0.000s, ALREADY EXISTS, row128, zh, 害怕
# 0.000s, ALREADY EXISTS, row128, zh, 羞愧
# 0.000s, ALREADY EXISTS, row128, english, to be afraid
# 0.000s, ALREADY EXISTS, row128, english, ashamed
# 0.000s, ALREADY EXISTS, row129, zh, 好客
# 0.000s, ALREADY EXISTS, row129, zh_slow, 好客
# 0.000s, ALREADY EXISTS, row129, english, hospitable
# 0.000s, ALREADY EXISTS, row129, zh, 好
# 0.000s, ALREADY EXISTS, row129, zh, 客
# 0.000s, ALREADY EXISTS, row129, english, good
# 0.000s, ALREADY EXISTS, row129, english, guest
# 0.000s, ALREADY EXISTS, row130, zh, 合理
# 0.000s, ALREADY EXISTS, row130, zh_slow, 合理
# 0.000s, ALREADY EXISTS, row130, english, rational;reasonable;fair
# 0.000s, ALREADY EXISTS, row130, zh, 合适
# 0.000s, ALREADY EXISTS, row130, zh, 理
# 0.000s, ALREADY EXISTS, row130, english, fitting
# 0.000s, ALREADY EXISTS, row130, english, reason
# 0.000s, ALREADY EXISTS, row131, zh, 好处
# 0.000s, ALREADY EXISTS, row131, zh_slow, 好处
# 0.000s, ALREADY EXISTS, row131, english, benefit;advantage;pro
# 0.000s, ALREADY EXISTS, row131, zh, 好
# 0.000s, ALREADY EXISTS, row131, zh, 处理
# 0.000s, ALREADY EXISTS, row131, english, good
# 0.000s, ALREADY EXISTS, row131, english, to handle
# 0.000s, ALREADY EXISTS, row132, zh, 价值
# 0.000s, ALREADY EXISTS, row132, zh_slow, 价值
# 0.000s, ALREADY EXISTS, row132, english, values;value
# 0.000s, ALREADY EXISTS, row132, zh, 价格
# 0.000s, ALREADY EXISTS, row132, zh, 值得
# 0.000s, ALREADY EXISTS, row132, english, price
# 0.000s, ALREADY EXISTS, row132, english, to be worth
# 0.000s, ALREADY EXISTS, row133, zh, 极简主义
# 0.000s, ALREADY EXISTS, row133, zh_slow, 极简主义
# 0.000s, ALREADY EXISTS, row133, english, minimalism
# 0.000s, ALREADY EXISTS, row133, zh, 极
# 0.000s, ALREADY EXISTS, row133, zh, 简
# 0.000s, ALREADY EXISTS, row133, english, extremely
# 0.000s, ALREADY EXISTS, row133, english, simple
# 0.000s, ALREADY EXISTS, row133, zh, 主义
# 0.000s, ALREADY EXISTS, row133, english, ideology
# 0.000s, ALREADY EXISTS, row134, zh, 宽容
# 0.000s, ALREADY EXISTS, row134, zh_slow, 宽容
# 0.000s, ALREADY EXISTS, row134, english, lenient;tolerant
# 0.000s, ALREADY EXISTS, row134, zh, 宽
# 0.000s, ALREADY EXISTS, row134, zh, 容易
# 0.000s, ALREADY EXISTS, row134, english, wide
# 0.000s, ALREADY EXISTS, row134, english, easy
# 0.000s, ALREADY EXISTS, row135, zh, 开明
# 0.000s, ALREADY EXISTS, row135, zh_slow, 开明
# 0.000s, ALREADY EXISTS, row135, english, open-minded;enlightened
# 0.000s, ALREADY EXISTS, row135, zh, 开
# 0.000s, ALREADY EXISTS, row135, zh, 明
# 0.000s, ALREADY EXISTS, row135, english, open
# 0.000s, ALREADY EXISTS, row135, english, bright
# 0.000s, ALREADY EXISTS, row136, zh, 可信
# 0.000s, ALREADY EXISTS, row136, zh_slow, 可信
# 0.000s, ALREADY EXISTS, row136, english, reliable
# 0.000s, ALREADY EXISTS, row136, zh, 可
# 0.000s, ALREADY EXISTS, row136, zh, 相信
# 0.000s, ALREADY EXISTS, row136, english, can
# 0.000s, ALREADY EXISTS, row136, english, to believe
# 0.000s, ALREADY EXISTS, row137, zh, 乐观
# 0.000s, ALREADY EXISTS, row137, zh_slow, 乐观
# 0.000s, ALREADY EXISTS, row137, english, optimistic
# 0.000s, ALREADY EXISTS, row137, zh, 快乐
# 0.000s, ALREADY EXISTS, row137, zh, 观点
# 0.000s, ALREADY EXISTS, row137, english, happy
# 0.000s, ALREADY EXISTS, row137, english, point of view
# 0.000s, ALREADY EXISTS, row138, zh, 迷信
# 0.000s, ALREADY EXISTS, row138, zh_slow, 迷信
# 0.000s, ALREADY EXISTS, row138, english, superstitious;superstitions
# 0.000s, ALREADY EXISTS, row138, zh, 迷路
# 0.000s, ALREADY EXISTS, row138, zh, 相信
# 0.000s, ALREADY EXISTS, row138, english, to lose the way
# 0.000s, ALREADY EXISTS, row138, english, to believe
# 0.000s, ALREADY EXISTS, row139, zh, 马虎
# 0.000s, ALREADY EXISTS, row139, zh_slow, 马虎
# 0.000s, ALREADY EXISTS, row139, english, careless;sloppy
# 0.000s, ALREADY EXISTS, row139, zh, 马
# 0.000s, ALREADY EXISTS, row139, zh, 虎
# 0.000s, ALREADY EXISTS, row139, english, horse
# 0.000s, ALREADY EXISTS, row139, english, tiger
# 0.000s, ALREADY EXISTS, row140, zh, 年轻
# 0.000s, ALREADY EXISTS, row140, zh_slow, 年轻
# 0.000s, ALREADY EXISTS, row140, english, young
# 0.000s, ALREADY EXISTS, row140, zh, 年
# 0.000s, ALREADY EXISTS, row140, zh, 轻
# 0.000s, ALREADY EXISTS, row140, english, year
# 0.000s, ALREADY EXISTS, row140, english, light
# 0.000s, ALREADY EXISTS, row141, zh, 普信男
# 0.000s, ALREADY EXISTS, row141, zh_slow, 普信男
# 0.000s, ALREADY EXISTS, row141, english, ordinary but confident man
# 0.000s, ALREADY EXISTS, row141, zh, 普通
# 0.000s, ALREADY EXISTS, row141, zh, 自信
# 0.000s, ALREADY EXISTS, row141, english, ordinary
# 0.000s, ALREADY EXISTS, row141, english, confident
# 0.000s, ALREADY EXISTS, row141, zh, 男
# 0.000s, ALREADY EXISTS, row141, english, man
# 0.000s, ALREADY EXISTS, row142, zh, 缺点
# 0.000s, ALREADY EXISTS, row142, zh_slow, 缺点
# 0.000s, ALREADY EXISTS, row142, english, shortcoming;disadvantage;con
# 0.000s, ALREADY EXISTS, row142, zh, 缺
# 0.000s, ALREADY EXISTS, row142, zh, 点
# 0.000s, ALREADY EXISTS, row142, english, lack
# 0.000s, ALREADY EXISTS, row142, english, point
# 0.000s, ALREADY EXISTS, row143, zh, 情商
# 0.000s, ALREADY EXISTS, row143, zh_slow, 情商
# 0.000s, ALREADY EXISTS, row143, english, emotional intelligence;EQ
# 0.000s, ALREADY EXISTS, row143, zh, 感情
# 0.000s, ALREADY EXISTS, row143, zh, 智商
# 0.000s, ALREADY EXISTS, row143, english, emotion
# 0.000s, ALREADY EXISTS, row143, english, IQ
# 0.000s, ALREADY EXISTS, row144, zh, 亲热
# 0.000s, ALREADY EXISTS, row144, zh_slow, 亲热
# 0.000s, ALREADY EXISTS, row144, english, affectionate
# 0.000s, ALREADY EXISTS, row144, zh, 亲密
# 0.000s, ALREADY EXISTS, row144, zh, 热
# 0.000s, ALREADY EXISTS, row144, english, intimate
# 0.000s, ALREADY EXISTS, row144, english, hot
# 0.000s, ALREADY EXISTS, row145, zh, 弱点
# 0.000s, ALREADY EXISTS, row145, zh_slow, 弱点
# 0.000s, ALREADY EXISTS, row145, english, weakness
# 0.000s, ALREADY EXISTS, row145, zh, 弱
# 0.000s, ALREADY EXISTS, row145, zh, 点
# 0.000s, ALREADY EXISTS, row145, english, weak
# 0.000s, ALREADY EXISTS, row145, english, point
# 0.000s, ALREADY EXISTS, row146, zh, 热闹
# 0.000s, ALREADY EXISTS, row146, zh_slow, 热闹
# 0.000s, ALREADY EXISTS, row146, english, lively
# 0.000s, ALREADY EXISTS, row146, zh, 热
# 0.000s, ALREADY EXISTS, row146, zh, 闹
# 0.000s, ALREADY EXISTS, row146, english, hot
# 0.000s, ALREADY EXISTS, row146, english, noisy
# 0.000s, ALREADY EXISTS, row147, zh, 容易相处
# 0.000s, ALREADY EXISTS, row147, zh_slow, 容易相处
# 0.000s, ALREADY EXISTS, row147, english, easygoing
# 0.000s, ALREADY EXISTS, row147, zh, 容易
# 0.000s, ALREADY EXISTS, row147, zh, 相处
# 0.000s, ALREADY EXISTS, row147, english, easy
# 0.000s, ALREADY EXISTS, row147, english, get along
# 0.000s, ALREADY EXISTS, row148, zh, 双重标准
# 0.000s, ALREADY EXISTS, row148, zh_slow, 双重标准
# 0.000s, ALREADY EXISTS, row148, english, double standards
# 0.000s, ALREADY EXISTS, row148, zh, 双重
# 0.000s, ALREADY EXISTS, row148, zh, 标准
# 0.000s, ALREADY EXISTS, row148, english, double
# 0.000s, ALREADY EXISTS, row148, english, standard
# 0.000s, ALREADY EXISTS, row149, zh, 神秘
# 0.000s, ALREADY EXISTS, row149, zh_slow, 神秘
# 0.000s, ALREADY EXISTS, row149, english, mysterious;mystery
# 0.000s, ALREADY EXISTS, row149, zh, 精神
# 0.000s, ALREADY EXISTS, row149, zh, 秘密
# 0.000s, ALREADY EXISTS, row149, english, spirit
# 0.000s, ALREADY EXISTS, row149, english, secret
# 0.000s, ALREADY EXISTS, row150, zh, 傻瓜
# 0.000s, ALREADY EXISTS, row150, zh_slow, 傻瓜
# 0.000s, ALREADY EXISTS, row150, english, idiot
# 0.000s, ALREADY EXISTS, row150, zh, 傻
# 0.000s, ALREADY EXISTS, row150, zh, 瓜
# 0.000s, ALREADY EXISTS, row150, english, stupid
# 0.000s, ALREADY EXISTS, row150, english, melon
# 0.000s, ALREADY EXISTS, row151, zh, 随性
# 0.000s, ALREADY EXISTS, row151, zh_slow, 随性
# 0.000s, ALREADY EXISTS, row151, english, casual
# 0.000s, ALREADY EXISTS, row151, zh, 随便
# 0.000s, ALREADY EXISTS, row151, zh, 性
# 0.000s, ALREADY EXISTS, row151, english, as one wishes
# 0.000s, ALREADY EXISTS, row151, english, nature
# 0.000s, ALREADY EXISTS, row152, zh, 调皮
# ...
# 0.000s, ALREADY EXISTS, row862, zh, 设备
# 0.000s, ALREADY EXISTS, row862, english, back
# 0.000s, ALREADY EXISTS, row862, english, equipment
# 0.000s, ALREADY EXISTS, row862, zh, 箱
# 0.000s, ALREADY EXISTS, row862, english, box
# 0.000s, ALREADY EXISTS, row863, zh, 海外
# 0.000s, ALREADY EXISTS, row863, zh_slow, 海外
# 0.000s, ALREADY EXISTS, row863, english, overseas
# 0.000s, ALREADY EXISTS, row863, zh, 海
# 0.000s, ALREADY EXISTS, row863, zh, 外
# 0.000s, ALREADY EXISTS, row863, english, sea
# 0.000s, ALREADY EXISTS, row863, english, outside
# 0.000s, ALREADY EXISTS, row864, zh, 纪念品
# 0.000s, ALREADY EXISTS, row864, zh_slow, 纪念品
# 0.000s, ALREADY EXISTS, row864, english, souvenir
# 0.000s, ALREADY EXISTS, row864, zh, 纪念
# 0.000s, ALREADY EXISTS, row864, zh, 品
# 0.000s, ALREADY EXISTS, row864, english, commemorate
# 0.000s, ALREADY EXISTS, row864, english, product
# 0.000s, ALREADY EXISTS, row865, zh, 居住证
# 0.000s, ALREADY EXISTS, row865, zh_slow, 居住证
# 0.000s, ALREADY EXISTS, row865, english, residence permit
# 0.000s, ALREADY EXISTS, row865, zh, 居住
# 0.000s, ALREADY EXISTS, row865, zh, 身份证
# 0.000s, ALREADY EXISTS, row865, english, to reside
# 0.000s, ALREADY EXISTS, row865, english, ID
# 0.000s, ALREADY EXISTS, row866, zh, 卡车
# 0.000s, ALREADY EXISTS, row866, zh_slow, 卡车
# 0.000s, ALREADY EXISTS, row866, english, truck
# 0.000s, ALREADY EXISTS, row866, zh, 卡
# 0.000s, ALREADY EXISTS, row866, zh, 车
# 0.000s, ALREADY EXISTS, row866, english, card
# 0.000s, ALREADY EXISTS, row866, english, vehicle
# 0.000s, ALREADY EXISTS, row867, zh, 流浪
# 0.000s, ALREADY EXISTS, row867, zh_slow, 流浪
# 0.000s, ALREADY EXISTS, row867, english, wandering;to wander
# 0.000s, ALREADY EXISTS, row867, zh, 流
# 0.000s, ALREADY EXISTS, row867, zh, 浪费
# 0.000s, ALREADY EXISTS, row867, english, to flow
# 0.000s, ALREADY EXISTS, row867, english, to waste
# 0.000s, ALREADY EXISTS, row868, zh, 路标
# 0.000s, ALREADY EXISTS, row868, zh_slow, 路标
# 0.000s, ALREADY EXISTS, row868, english, road signs
# 0.000s, ALREADY EXISTS, row868, zh, 路
# 0.000s, ALREADY EXISTS, row868, zh, 标
# 0.000s, ALREADY EXISTS, row868, english, road
# 0.000s, ALREADY EXISTS, row868, english, sign
# 0.000s, ALREADY EXISTS, row869, zh, 缆车
# 0.000s, ALREADY EXISTS, row869, zh_slow, 缆车
# 0.000s, ALREADY EXISTS, row869, english, cable car
# 0.000s, ALREADY EXISTS, row869, zh, 缆
# 0.000s, ALREADY EXISTS, row869, zh, 车
# 0.000s, ALREADY EXISTS, row869, english, cable
# 0.000s, ALREADY EXISTS, row869, english, vehicle
# 0.000s, ALREADY EXISTS, row870, zh, 旅居
# 0.000s, ALREADY EXISTS, row870, zh_slow, 旅居
# 0.000s, ALREADY EXISTS, row870, english, live abroad (temporarily)
# 0.000s, ALREADY EXISTS, row870, zh, 旅行
# 0.000s, ALREADY EXISTS, row870, zh, 居民
# 0.000s, ALREADY EXISTS, row870, english, travel
# 0.000s, ALREADY EXISTS, row870, english, resident
# 0.000s, ALREADY EXISTS, row871, zh, 旅游团
# 0.000s, ALREADY EXISTS, row871, zh_slow, 旅游团
# 0.000s, ALREADY EXISTS, row871, english, tour group
# 0.000s, ALREADY EXISTS, row871, zh, 旅游
# 0.000s, ALREADY EXISTS, row871, zh, 团
# 0.000s, ALREADY EXISTS, row871, english, tourism
# 0.000s, ALREADY EXISTS, row871, english, group
# 0.000s, ALREADY EXISTS, row872, zh, 气候
# 0.000s, ALREADY EXISTS, row872, zh_slow, 气候
# 0.000s, ALREADY EXISTS, row872, english, climate
# 0.000s, ALREADY EXISTS, row872, zh, 气
# 0.000s, ALREADY EXISTS, row872, zh, 时候
# 0.000s, ALREADY EXISTS, row872, english, air
# 0.000s, ALREADY EXISTS, row872, english, time
# 0.000s, ALREADY EXISTS, row873, zh, 汽油
# 0.000s, ALREADY EXISTS, row873, zh_slow, 汽油
# 0.000s, ALREADY EXISTS, row873, english, gasoline
# 0.000s, ALREADY EXISTS, row873, zh, 汽
# 0.000s, ALREADY EXISTS, row873, zh, 油
# 0.000s, ALREADY EXISTS, row873, english, gas
# 0.000s, ALREADY EXISTS, row873, english, oil
# 0.000s, ALREADY EXISTS, row874, zh, 起飞
# 0.000s, ALREADY EXISTS, row874, zh_slow, 起飞
# 0.000s, ALREADY EXISTS, row874, english, to take off (plane)
# 0.000s, ALREADY EXISTS, row874, zh, 起来
# 0.000s, ALREADY EXISTS, row874, zh, 飞
# 0.000s, ALREADY EXISTS, row874, english, to get up
# 0.000s, ALREADY EXISTS, row874, english, to fly
# 0.000s, ALREADY EXISTS, row875, zh, 入住
# 0.000s, ALREADY EXISTS, row875, zh_slow, 入住
# 0.000s, ALREADY EXISTS, row875, english, check-in
# 0.000s, ALREADY EXISTS, row875, zh, 入
# 0.000s, ALREADY EXISTS, row875, zh, 住
# 0.000s, ALREADY EXISTS, row875, english, enter
# 0.000s, ALREADY EXISTS, row875, english, to reside
# 0.000s, ALREADY EXISTS, row876, zh, 沙漠
# 0.000s, ALREADY EXISTS, row876, zh_slow, 沙漠
# 0.000s, ALREADY EXISTS, row876, english, desert
# 0.000s, ALREADY EXISTS, row876, zh, 沙
# 0.000s, ALREADY EXISTS, row876, zh, 冷漠
# 0.000s, ALREADY EXISTS, row876, english, sand
# 0.000s, ALREADY EXISTS, row876, english, indifferent
# 0.000s, ALREADY EXISTS, row877, zh, 首都
# 0.000s, ALREADY EXISTS, row877, zh_slow, 首都
# 0.000s, ALREADY EXISTS, row877, english, capital (city)
# 0.000s, ALREADY EXISTS, row877, zh, 首
# 0.000s, ALREADY EXISTS, row877, zh, 都
# 0.000s, ALREADY EXISTS, row877, english, head;first
# 0.000s, ALREADY EXISTS, row877, english, all;metropolis
# 0.000s, ALREADY EXISTS, row878, zh, 随身
# 0.000s, ALREADY EXISTS, row878, zh_slow, 随身
# 0.000s, ALREADY EXISTS, row878, english, carry-on
# 0.000s, ALREADY EXISTS, row878, zh, 随便
# 0.000s, ALREADY EXISTS, row878, zh, 身
# 0.000s, ALREADY EXISTS, row878, english, as one wishes
# 0.000s, ALREADY EXISTS, row878, english, body
# 0.000s, ALREADY EXISTS, row879, zh, 天气预报
# 0.000s, ALREADY EXISTS, row879, zh_slow, 天气预报
# 0.000s, ALREADY EXISTS, row879, english, weather forecast
# 0.000s, ALREADY EXISTS, row879, zh, 天气
# 0.000s, ALREADY EXISTS, row879, zh, 预期
# 0.000s, ALREADY EXISTS, row879, english, weather
# 0.000s, ALREADY EXISTS, row879, english, to expect
# 0.000s, ALREADY EXISTS, row879, zh, 报
# 0.000s, ALREADY EXISTS, row879, english, report
# 0.000s, ALREADY EXISTS, row880, zh, 唐人街
# 0.000s, ALREADY EXISTS, row880, zh_slow, 唐人街
# 0.000s, ALREADY EXISTS, row880, english, Chinatown
# 0.000s, ALREADY EXISTS, row880, zh, 唐代
# 0.000s, ALREADY EXISTS, row880, zh, 人
# 0.000s, ALREADY EXISTS, row880, english, Tang Dynasty
# 0.000s, ALREADY EXISTS, row880, english, person
# 0.000s, ALREADY EXISTS, row880, zh, 街
# 0.000s, ALREADY EXISTS, row880, english, street
# 0.000s, ALREADY EXISTS, row881, zh, 头等舱
# 0.000s, ALREADY EXISTS, row881, zh_slow, 头等舱
# 0.000s, ALREADY EXISTS, row881, english, first class
# 0.000s, ALREADY EXISTS, row881, zh, 头
# 0.000s, ALREADY EXISTS, row881, zh, 等
# 0.000s, ALREADY EXISTS, row881, english, head
# 0.000s, ALREADY EXISTS, row881, english, rank
# 0.000s, ALREADY EXISTS, row881, zh, 舱
# 0.000s, ALREADY EXISTS, row881, english, cabin
# 0.000s, ALREADY EXISTS, row882, zh, 问路
# 0.000s, ALREADY EXISTS, row882, zh_slow, 问路
# 0.000s, ALREADY EXISTS, row882, english, ask for directions
# 0.000s, ALREADY EXISTS, row882, zh, 问
# 0.000s, ALREADY EXISTS, row882, zh, 路
# 0.000s, ALREADY EXISTS, row882, english, ask
# 0.000s, ALREADY EXISTS, row882, english, road
# 0.000s, ALREADY EXISTS, row883, zh, 往返
# 0.000s, ALREADY EXISTS, row883, zh_slow, 往返
# 0.000s, ALREADY EXISTS, row883, english, round trip
# 0.000s, ALREADY EXISTS, row883, zh, 往
# 0.000s, ALREADY EXISTS, row883, zh, 返
# 0.000s, ALREADY EXISTS, row883, english, go
# 0.000s, ALREADY EXISTS, row883, english, to return
# 0.000s, ALREADY EXISTS, row884, zh, 乡村
# 0.000s, ALREADY EXISTS, row884, zh_slow, 乡村
# 0.000s, ALREADY EXISTS, row884, english, countryside;rural
# 0.000s, ALREADY EXISTS, row884, zh, 家乡
# 0.000s, ALREADY EXISTS, row884, zh, 村
# 0.000s, ALREADY EXISTS, row884, english, hometown
# 0.000s, ALREADY EXISTS, row884, english, village
# 0.000s, ALREADY EXISTS, row885, zh, 小费
# 0.000s, ALREADY EXISTS, row885, zh_slow, 小费
# 0.000s, ALREADY EXISTS, row885, english, tip
# 0.000s, ALREADY EXISTS, row885, zh, 小
# 0.000s, ALREADY EXISTS, row885, zh, 费
# 0.000s, ALREADY EXISTS, row885, english, small
# 0.000s, ALREADY EXISTS, row885, english, fee
# 0.000s, ALREADY EXISTS, row886, zh, 信用卡
# 0.000s, ALREADY EXISTS, row886, zh_slow, 信用卡
# 0.000s, ALREADY EXISTS, row886, english, credit card
# 0.000s, ALREADY EXISTS, row886, zh, 信任
# 0.000s, ALREADY EXISTS, row886, zh, 用
# 0.000s, ALREADY EXISTS, row886, english, to trust
# 0.000s, ALREADY EXISTS, row886, english, to use
# 0.000s, ALREADY EXISTS, row886, zh, 卡
# 0.000s, ALREADY EXISTS, row886, english, card
# 0.000s, ALREADY EXISTS, row887, zh, 行李
# 0.000s, ALREADY EXISTS, row887, zh_slow, 行李
# 0.000s, ALREADY EXISTS, row887, english, luggage
# 0.000s, ALREADY EXISTS, row887, zh, 行
# 0.000s, ALREADY EXISTS, row887, zh, 李
# 0.000s, ALREADY EXISTS, row887, english, to walk
# 0.000s, ALREADY EXISTS, row887, english, plum
# 0.000s, ALREADY EXISTS, row888, zh, 行李箱
# 0.000s, ALREADY EXISTS, row888, zh_slow, 行李箱
# 0.000s, ALREADY EXISTS, row888, english, suitcase
# 0.000s, ALREADY EXISTS, row888, zh, 行李
# 0.000s, ALREADY EXISTS, row888, zh, 箱
# 0.000s, ALREADY EXISTS, row888, english, luggage
# 0.000s, ALREADY EXISTS, row888, english, box
# 0.000s, ALREADY EXISTS, row889, zh, 移民
# 0.000s, ALREADY EXISTS, row889, zh_slow, 移民
# 0.000s, ALREADY EXISTS, row889, english, immigrant;to migrate
# 0.000s, ALREADY EXISTS, row889, zh, 移
# 0.000s, ALREADY EXISTS, row889, zh, 民
# 0.000s, ALREADY EXISTS, row889, english, to move
# 0.000s, ALREADY EXISTS, row889, english, people
# 0.000s, ALREADY EXISTS, row890, zh, 晕车
# 0.000s, ALREADY EXISTS, row890, zh_slow, 晕车
# 0.000s, ALREADY EXISTS, row890, english, carsick
# 0.000s, ALREADY EXISTS, row890, zh, 头晕
# 0.000s, ALREADY EXISTS, row890, zh, 车
# 0.000s, ALREADY EXISTS, row890, english, dizzy
# 0.000s, ALREADY EXISTS, row890, english, car
# 0.000s, ALREADY EXISTS, row891, zh, 早高峰
# 0.000s, ALREADY EXISTS, row891, zh_slow, 早高峰
# 0.000s, ALREADY EXISTS, row891, english, morning rush hour
# 0.000s, ALREADY EXISTS, row891, zh, 早
# 0.000s, ALREADY EXISTS, row891, zh, 高
# 0.000s, ALREADY EXISTS, row891, english, morning
# 0.000s, ALREADY EXISTS, row891, english, high
# 0.000s, ALREADY EXISTS, row891, zh, 峰
# 0.000s, ALREADY EXISTS, row891, english, peak
# 0.000s, ALREADY EXISTS, row892, zh, 安全带
# 0.000s, ALREADY EXISTS, row892, zh_slow, 安全带
# 0.000s, ALREADY EXISTS, row892, english, seat belt;safety belt
# 0.000s, ALREADY EXISTS, row892, zh, 安全
# 0.000s, ALREADY EXISTS, row892, zh, 带
# 0.000s, ALREADY EXISTS, row892, english, safety
# 0.000s, ALREADY EXISTS, row892, english, belt
# 0.000s, ALREADY EXISTS, row893, zh, 打断
# 0.000s, ALREADY EXISTS, row893, zh_slow, 打断
# 0.000s, ALREADY EXISTS, row893, english, to interrupt
# 0.000s, ALREADY EXISTS, row893, zh, 打
# 0.000s, ALREADY EXISTS, row893, zh, 断裂
# 0.000s, ALREADY EXISTS, row893, english, to hit
# 0.000s, ALREADY EXISTS, row893, english, fracture
# 0.000s, ALREADY EXISTS, row894, zh, 发现
# 0.000s, ALREADY EXISTS, row894, zh_slow, 发现
# 0.000s, ALREADY EXISTS, row894, english, to discover
# 0.000s, ALREADY EXISTS, row894, zh, 发
# 0.000s, ALREADY EXISTS, row894, zh, 表现
# 0.000s, ALREADY EXISTS, row894, english, to send out
# 0.000s, ALREADY EXISTS, row894, english, to show
# 0.000s, ALREADY EXISTS, row895, zh, 反对
# 0.000s, ALREADY EXISTS, row895, zh_slow, 反对
# 0.000s, ALREADY EXISTS, row895, english, to oppose
# 0.000s, ALREADY EXISTS, row895, zh, 反
# 0.000s, ALREADY EXISTS, row895, zh, 对
# 0.000s, ALREADY EXISTS, row895, english, anti
# 0.000s, ALREADY EXISTS, row895, english, correct
# 0.000s, ALREADY EXISTS, row896, zh, 反思
# 0.000s, ALREADY EXISTS, row896, zh_slow, 反思
# 0.000s, ALREADY EXISTS, row896, english, to reassess;review;rethink
# 0.000s, ALREADY EXISTS, row896, zh, 反
# 0.000s, ALREADY EXISTS, row896, zh, 思
# 0.000s, ALREADY EXISTS, row896, english, opposite
# 0.000s, ALREADY EXISTS, row896, english, think
# 0.000s, ALREADY EXISTS, row897, zh, 纪念
# 0.000s, ALREADY EXISTS, row897, zh_slow, 纪念
# 0.000s, ALREADY EXISTS, row897, english, to commemorate
# 0.000s, ALREADY EXISTS, row897, zh, 世纪
# 0.000s, ALREADY EXISTS, row897, zh, 想念
# 0.000s, ALREADY EXISTS, row897, english, century
# 0.000s, ALREADY EXISTS, row897, english, to miss
# 0.000s, ALREADY EXISTS, row898, zh, 考虑
# 0.000s, ALREADY EXISTS, row898, zh_slow, 考虑
# 0.000s, ALREADY EXISTS, row898, english, to consider;think over
# 0.000s, ALREADY EXISTS, row898, zh, 考试
# 0.000s, ALREADY EXISTS, row898, zh, 焦虑
# 0.000s, ALREADY EXISTS, row898, english, exam
# 0.000s, ALREADY EXISTS, row898, english, anxious
# 0.000s, ALREADY EXISTS, row899, zh, 理解
# 0.000s, ALREADY EXISTS, row899, zh_slow, 理解
# 0.000s, ALREADY EXISTS, row899, english, to understand;comprehend
# 0.000s, ALREADY EXISTS, row899, zh, 管理
# 0.000s, ALREADY EXISTS, row899, zh, 解决
# 0.000s, ALREADY EXISTS, row899, english, to manage
# 0.000s, ALREADY EXISTS, row899, english, to resolve
# 0.000s, ALREADY EXISTS, row900, zh, 说明
# 0.000s, ALREADY EXISTS, row900, zh_slow, 说明
# 0.000s, ALREADY EXISTS, row900, english, to explain;show;prove;illustrate
# 0.000s, ALREADY EXISTS, row900, zh, 说
# 0.000s, ALREADY EXISTS, row900, zh, 明
# 0.000s, ALREADY EXISTS, row900, english, to speak
# 0.000s, ALREADY EXISTS, row900, english, bright
# 0.000s, ALREADY EXISTS, row901, zh, 提出
# 0.000s, ALREADY EXISTS, row901, zh_slow, 提出
# 0.000s, ALREADY EXISTS, row901, english, to suggest;propose
# 0.000s, ALREADY EXISTS, row901, zh, 提供
# 0.000s, ALREADY EXISTS, row901, zh, 出
# 0.000s, ALREADY EXISTS, row901, english, to offer
# 0.000s, ALREADY EXISTS, row901, english, go out
# 0.000s, ALREADY EXISTS, row902, zh, 提到
# 0.000s, ALREADY EXISTS, row902, zh_slow, 提到
# 0.000s, ALREADY EXISTS, row902, english, mentioned
# 0.000s, ALREADY EXISTS, row902, zh, 提供
# 0.000s, ALREADY EXISTS, row902, zh, 到
# 0.000s, ALREADY EXISTS, row902, english, to offer
# 0.000s, ALREADY EXISTS, row902, english, to arrive
# 0.000s, ALREADY EXISTS, row903, zh, 提供
# 0.000s, ALREADY EXISTS, row903, zh_slow, 提供
# 0.000s, ALREADY EXISTS, row903, english, to offer
# 0.000s, ALREADY EXISTS, row903, zh, 提
# 0.000s, ALREADY EXISTS, row903, zh, 供
# 0.000s, ALREADY EXISTS, row903, english, to lift
# 0.000s, ALREADY EXISTS, row903, english, to provide
# 0.000s, ALREADY EXISTS, row904, zh, 提示
# 0.000s, ALREADY EXISTS, row904, zh_slow, 提示
# 0.000s, ALREADY EXISTS, row904, english, hint;remind;suggest;tip
# 0.000s, ALREADY EXISTS, row904, zh, 提供
# 0.000s, ALREADY EXISTS, row904, zh, 表示
# 0.000s, ALREADY EXISTS, row904, english, to offer
# 0.000s, ALREADY EXISTS, row904, english, to show
# 0.000s, ALREADY EXISTS, row905, zh, 偷走
# 0.000s, ALREADY EXISTS, row905, zh_slow, 偷走
# 0.000s, ALREADY EXISTS, row905, english, stolen;steal
# 0.000s, ALREADY EXISTS, row905, zh, 小偷
# 0.000s, ALREADY EXISTS, row905, zh, 走
# 0.000s, ALREADY EXISTS, row905, english, thief
# 0.000s, ALREADY EXISTS, row905, english, to walk
# 0.000s, ALREADY EXISTS, row906, zh, 维持
# 0.000s, ALREADY EXISTS, row906, zh_slow, 维持
# 0.000s, ALREADY EXISTS, row906, english, to maintain;keep
# 0.000s, ALREADY EXISTS, row906, zh, 维修
# 0.000s, ALREADY EXISTS, row906, zh, 支持
# 0.000s, ALREADY EXISTS, row906, english, to repair
# 0.000s, ALREADY EXISTS, row906, english, to support
# 0.000s, ALREADY EXISTS, row907, zh, 修改
# 0.000s, ALREADY EXISTS, row907, zh_slow, 修改
# 0.000s, ALREADY EXISTS, row907, english, to amend;modify
# 0.000s, ALREADY EXISTS, row907, zh, 装修
# 0.000s, ALREADY EXISTS, row907, zh, 改
# 0.000s, ALREADY EXISTS, row907, english, to decorate
# 0.000s, ALREADY EXISTS, row907, english, change
# 0.000s, ALREADY EXISTS, row908, zh, 预报
# 0.000s, ALREADY EXISTS, row908, zh_slow, 预报
# 0.000s, ALREADY EXISTS, row908, english, forecast
# 0.000s, ALREADY EXISTS, row908, zh, 预期
# 0.000s, ALREADY EXISTS, row908, zh, 报
# 0.000s, ALREADY EXISTS, row908, english, to expect
# 0.000s, ALREADY EXISTS, row908, english, report
# 0.000s, ALREADY EXISTS, row909, zh, 造成
# 0.000s, ALREADY EXISTS, row909, zh_slow, 造成
# 0.000s, ALREADY EXISTS, row909, english, to cause;to bring about
# 0.000s, ALREADY EXISTS, row909, zh, 造
# 0.000s, ALREADY EXISTS, row909, zh, 成为
# 0.000s, ALREADY EXISTS, row909, english, to make
# 0.000s, ALREADY EXISTS, row909, english, to become
# 0.000s, ALREADY EXISTS, row910, zh, 自杀
# 0.000s, ALREADY EXISTS, row910, zh_slow, 自杀
# 0.000s, ALREADY EXISTS, row910, english, suicide
# 0.000s, ALREADY EXISTS, row910, zh, 自
# 0.000s, ALREADY EXISTS, row910, zh, 杀
# 0.000s, ALREADY EXISTS, row910, english, self
# 0.000s, ALREADY EXISTS, row910, english, kill
# 0.000s, ALREADY EXISTS, row911, zh, 撒娇
# 0.000s, ALREADY EXISTS, row911, zh_slow, 撒娇
# 0.000s, ALREADY EXISTS, row911, english, to act spoiled;throw a tantrum
# 0.000s, ALREADY EXISTS, row911, zh, 撒谎
# 0.000s, ALREADY EXISTS, row911, zh, 娇
# 0.000s, ALREADY EXISTS, row911, english, to tell lies
# 0.000s, ALREADY EXISTS, row911, english, loveable

# %% [markdown]
# # 4. Combine files for individual vocab words

# %%
recording_id = '006'
recording_name = '0815_word_p2_k2_ecombo'
for i_row, row in df_this.iterrows():
    start_time = time.time()
    new_file_path = f"audio_files/rows/{recording_id}_{row['chinese']}.mp3"
    if not os.path.exists(new_file_path):
        chinese_audio = AudioSegment.from_mp3(f"audio_files/zh/{row['chinese']}.mp3")
        chinese_slow_audio = AudioSegment.from_mp3(f"audio_files/zh_slow/{row['chinese']}.mp3")
        english_audio = AudioSegment.from_mp3(f"audio_files/english/{row['english']}.mp3")
        
        word1_audio = AudioSegment.from_mp3(f"audio_files/zh/{row['word1']}.mp3")
        word2_audio = AudioSegment.from_mp3(f"audio_files/zh/{row['word2']}.mp3")
        word1e_audio = AudioSegment.from_mp3(f"audio_files/english/{row['word1_english']}.mp3")
        word2e_audio = AudioSegment.from_mp3(f"audio_files/english/{row['word2_english']}.mp3")
        if not pd.isna(row['word3']):
            word3_audio = AudioSegment.from_mp3(f"audio_files/zh/{row['word3']}.mp3")
            word3e_audio = AudioSegment.from_mp3(f"audio_files/english/{row['word3_english']}.mp3")
        if not pd.isna(row['word4']):
            word4_audio = AudioSegment.from_mp3(f"audio_files/zh/{row['word4']}.mp3")
            word4e_audio = AudioSegment.from_mp3(f"audio_files/english/{row['word4_english']}.mp3")
        
        pause_100ms = AudioSegment.silent(duration=100)
        pause_500ms = AudioSegment.silent(duration=500)
        pause_1000ms = AudioSegment.silent(duration=1000)

        # concat words audio
        component_words_audio = word1_audio + pause_100ms + word1e_audio + pause_500ms + word2_audio + pause_100ms + word2e_audio
        if not pd.isna(row['word3']):
            component_words_audio += pause_500ms + word3_audio + pause_100ms + word3e_audio
        if not pd.isna(row['word4']):
            component_words_audio += pause_500ms + word4_audio + pause_100ms + word4e_audio

        # 001
        # combined = chinese_audio + pause_500ms + chinese_slow_audio + pause_500ms + english_audio + pause_500ms + sent_audio + pause_500ms + sent_english_audio + pause_500ms + sent_audio + pause_1000ms
        # 002
        # combined = chinese_audio + pause_500ms + chinese_slow_audio + pause_500ms + english_audio + pause_500ms + sent_audio + pause_500ms + sent_audio + pause_1000ms

        # 003
        combined = chinese_audio + pause_500ms + component_words_audio + pause_500ms + chinese_slow_audio + pause_500ms + english_audio + pause_500ms
        
        combined.export(new_file_path, format="mp3")
        print(f"{(time.time()-start_time):.2f} seconds, row {i_row}, {row['chinese']}")
    else:
        print(f"{(time.time()-start_time):.2f} seconds, row {i_row}, {row['chinese']} ALREADY EXISTS")
# Out:
# 0.00 seconds, row 0, 标准 ALREADY EXISTS
# 0.00 seconds, row 1, 出名 ALREADY EXISTS
# 0.00 seconds, row 2, 大声 ALREADY EXISTS
# 0.00 seconds, row 3, 角度 ALREADY EXISTS
# 0.00 seconds, row 4, 主动 ALREADY EXISTS
# 0.00 seconds, row 5, 主观 ALREADY EXISTS
# 0.00 seconds, row 6, 自愿 ALREADY EXISTS
# 0.00 seconds, row 7, 百万 ALREADY EXISTS
# 0.00 seconds, row 8, 差不多 ALREADY EXISTS
# 0.00 seconds, row 9, 差点儿 ALREADY EXISTS
# 0.00 seconds, row 10, 差距 ALREADY EXISTS
# 0.00 seconds, row 11, 大部分 ALREADY EXISTS
# 0.00 seconds, row 12, 大多数 ALREADY EXISTS
# 0.00 seconds, row 13, 大概 ALREADY EXISTS
# 0.00 seconds, row 14, 大小 ALREADY EXISTS
# 0.00 seconds, row 15, 概率 ALREADY EXISTS
# 0.00 seconds, row 16, 高度 ALREADY EXISTS
# 0.00 seconds, row 17, 好几 ALREADY EXISTS
# 0.00 seconds, row 18, 几十 ALREADY EXISTS
# 0.00 seconds, row 19, 毛重 ALREADY EXISTS
# 0.00 seconds, row 20, 难得 ALREADY EXISTS
# 0.00 seconds, row 21, 频率 ALREADY EXISTS
# 0.00 seconds, row 22, 平方米 ALREADY EXISTS
# 0.00 seconds, row 23, 十亿 ALREADY EXISTS
# 0.00 seconds, row 24, 数量 ALREADY EXISTS
# 0.00 seconds, row 25, 微克 ALREADY EXISTS
# 0.00 seconds, row 26, 至少 ALREADY EXISTS
# 0.00 seconds, row 27, 重量 ALREADY EXISTS
# 0.00 seconds, row 28, 左右 ALREADY EXISTS
# 0.00 seconds, row 29, 八爪鱼 ALREADY EXISTS
# 0.00 seconds, row 30, 长颈鹿 ALREADY EXISTS
# 0.00 seconds, row 31, 飞虫 ALREADY EXISTS
# 0.00 seconds, row 32, 抚摸 ALREADY EXISTS
# 0.00 seconds, row 33, 黄牛 ALREADY EXISTS
# 0.00 seconds, row 34, 郊狼 ALREADY EXISTS
# 0.00 seconds, row 35, 恐龙 ALREADY EXISTS
# 0.00 seconds, row 36, 龙虾 ALREADY EXISTS
# 0.00 seconds, row 37, 毛皮 ALREADY EXISTS
# 0.00 seconds, row 38, 山羊 ALREADY EXISTS
# 0.00 seconds, row 39, 汪汪 ALREADY EXISTS
# 0.00 seconds, row 40, 项圈 ALREADY EXISTS
# 0.00 seconds, row 41, 博士 ALREADY EXISTS
# 0.00 seconds, row 42, 博士生导师 ALREADY EXISTS
# 0.00 seconds, row 43, 创始人 ALREADY EXISTS
# 0.00 seconds, row 44, 创业 ALREADY EXISTS
# 0.00 seconds, row 45, 程序员 ALREADY EXISTS
# 0.00 seconds, row 46, 产假 ALREADY EXISTS
# 0.00 seconds, row 47, 裁员 ALREADY EXISTS
# 0.00 seconds, row 48, 店长 ALREADY EXISTS
# 0.00 seconds, row 49, 队友 ALREADY EXISTS
# 0.00 seconds, row 50, 导师 ALREADY EXISTS
# 0.00 seconds, row 51, 房地产 ALREADY EXISTS
# 0.00 seconds, row 52, 发明 ALREADY EXISTS
# 0.00 seconds, row 53, 分公司 ALREADY EXISTS
# 0.00 seconds, row 54, 高级 ALREADY EXISTS
# 0.00 seconds, row 55, 工程 ALREADY EXISTS
# 0.00 seconds, row 56, 股票 ALREADY EXISTS
# 0.00 seconds, row 57, 股市 ALREADY EXISTS
# 0.00 seconds, row 58, 化学 ALREADY EXISTS
# 0.00 seconds, row 59, 会议室 ALREADY EXISTS
# 0.00 seconds, row 60, 解雇 ALREADY EXISTS
# 0.00 seconds, row 61, 简历 ALREADY EXISTS
# 0.00 seconds, row 62, 奖学金 ALREADY EXISTS
# 0.00 seconds, row 63, 技术 ALREADY EXISTS
# 0.00 seconds, row 64, 进口 ALREADY EXISTS
# 0.00 seconds, row 65, 机会 ALREADY EXISTS
# 0.00 seconds, row 66, 金融 ALREADY EXISTS
# 0.73 seconds, row 67, 经纪人
# 0.00 seconds, row 68, 经理 ALREADY EXISTS
# 0.00 seconds, row 69, 科目 ALREADY EXISTS
# 0.00 seconds, row 70, 老板 ALREADY EXISTS
# 0.57 seconds, row 71, 理论
# 0.00 seconds, row 72, 领域 ALREADY EXISTS
# 0.00 seconds, row 73, 面试 ALREADY EXISTS
# 0.00 seconds, row 74, 目标 ALREADY EXISTS
# 0.57 seconds, row 75, 脑科学
# 0.00 seconds, row 76, 全职 ALREADY EXISTS
# 0.57 seconds, row 77, 骑手
# 0.00 seconds, row 78, 实验 ALREADY EXISTS
# 0.00 seconds, row 79, 生产 ALREADY EXISTS
# 0.00 seconds, row 80, 升职 ALREADY EXISTS
# 0.00 seconds, row 81, 失业 ALREADY EXISTS
# 0.59 seconds, row 82, 收入
# 0.00 seconds, row 83, 天文 ALREADY EXISTS
# 0.00 seconds, row 84, 退出 ALREADY EXISTS
# 0.00 seconds, row 85, 退休 ALREADY EXISTS
# 0.58 seconds, row 86, 谈判
# 0.00 seconds, row 87, 同事 ALREADY EXISTS
# 0.00 seconds, row 88, 投入 ALREADY EXISTS
# 0.00 seconds, row 89, 投资 ALREADY EXISTS
# 0.00 seconds, row 90, 图表 ALREADY EXISTS
# 0.57 seconds, row 91, 统计
# 0.57 seconds, row 92, 外贸
# 0.00 seconds, row 93, 文件 ALREADY EXISTS
# 0.00 seconds, row 94, 物流 ALREADY EXISTS
# 0.00 seconds, row 95, 物理 ALREADY EXISTS
# 0.00 seconds, row 96, 校区 ALREADY EXISTS
# 0.00 seconds, row 97, 校园 ALREADY EXISTS
# 0.00 seconds, row 98, 学期 ALREADY EXISTS
# 0.00 seconds, row 99, 学术界 ALREADY EXISTS
# 0.57 seconds, row 100, 远程
# 0.00 seconds, row 101, 研一 ALREADY EXISTS
# 0.00 seconds, row 102, 演讲 ALREADY EXISTS
# 0.00 seconds, row 103, 专业 ALREADY EXISTS
# 0.77 seconds, row 104, 志愿者
# 0.00 seconds, row 105, 高级 ALREADY EXISTS
# 0.00 seconds, row 106, 降低 ALREADY EXISTS
# 0.61 seconds, row 107, 上一个
# 0.00 seconds, row 108, 提高 ALREADY EXISTS
# 0.60 seconds, row 109, 变态
# 0.59 seconds, row 110, 不礼貌
# 0.60 seconds, row 111, 创意
# 0.00 seconds, row 112, 抽象 ALREADY EXISTS
# 0.00 seconds, row 113, 出色 ALREADY EXISTS
# 0.75 seconds, row 114, 初学者
# 0.00 seconds, row 115, 才能 ALREADY EXISTS
# 0.60 seconds, row 116, 得体
# 0.60 seconds, row 117, 地道
# 0.00 seconds, row 118, 独立 ALREADY EXISTS
# 0.00 seconds, row 119, 独特 ALREADY EXISTS
# 0.58 seconds, row 120, 低调
# 0.00 seconds, row 121, 负面 ALREADY EXISTS
# 0.60 seconds, row 122, 复杂
# 0.61 seconds, row 123, 个人主义
# 0.00 seconds, row 124, 固执 ALREADY EXISTS
# 0.00 seconds, row 125, 高手 ALREADY EXISTS
# 0.64 seconds, row 126, 高效
# 0.00 seconds, row 127, 坏处 ALREADY EXISTS
# 0.61 seconds, row 128, 害羞
# 0.00 seconds, row 129, 好客 ALREADY EXISTS
# 0.00 seconds, row 130, 合理 ALREADY EXISTS
# 0.59 seconds, row 131, 好处
# 0.00 seconds, row 132, 价值 ALREADY EXISTS
# 0.00 seconds, row 133, 极简主义 ALREADY EXISTS
# 0.62 seconds, row 134, 宽容
# 0.00 seconds, row 135, 开明 ALREADY EXISTS
# 0.00 seconds, row 136, 可信 ALREADY EXISTS
# 0.62 seconds, row 137, 乐观
# 0.00 seconds, row 138, 迷信 ALREADY EXISTS
# 0.58 seconds, row 139, 马虎
# 0.00 seconds, row 140, 年轻 ALREADY EXISTS
# 0.75 seconds, row 141, 普信男
# 0.64 seconds, row 142, 缺点
# 0.62 seconds, row 143, 情商
# 0.00 seconds, row 144, 亲热 ALREADY EXISTS
# 0.59 seconds, row 145, 弱点
# 0.59 seconds, row 146, 热闹
# 0.58 seconds, row 147, 容易相处
# 0.70 seconds, row 148, 双重标准
# 0.00 seconds, row 149, 神秘 ALREADY EXISTS
# 0.00 seconds, row 150, 傻瓜 ALREADY EXISTS
# 0.59 seconds, row 151, 随性
# 0.66 seconds, row 152, 调皮
# 0.00 seconds, row 153, 天才 ALREADY EXISTS
# 0.00 seconds, row 154, 天真 ALREADY EXISTS
# 0.80 seconds, row 155, 体贴
# 0.00 seconds, row 156, 外表 ALREADY EXISTS
# 0.76 seconds, row 157, 油腻男
# 0.00 seconds, row 158, 野心 ALREADY EXISTS
# 0.62 seconds, row 159, 优点
# 0.00 seconds, row 160, 眼熟 ALREADY EXISTS
# 0.60 seconds, row 161, 友好
# 0.00 seconds, row 162, 有礼貌 ALREADY EXISTS
# 0.00 seconds, row 163, 正宗 ALREADY EXISTS
# 0.00 seconds, row 164, 智障 ALREADY EXISTS
# 0.61 seconds, row 165, 著名
# 0.77 seconds, row 166, 自卑
# 0.00 seconds, row 167, 自大 ALREADY EXISTS
# 0.63 seconds, row 168, 自律
# 0.00 seconds, row 169, 自私 ALREADY EXISTS
# 0.00 seconds, row 170, 自信 ALREADY EXISTS
# 0.67 seconds, row 171, 傲慢
# 0.00 seconds, row 172, 耳熟 ALREADY EXISTS
# 0.00 seconds, row 173, 爆竹 ALREADY EXISTS
# 0.00 seconds, row 174, 长江 ALREADY EXISTS
# 0.86 seconds, row 175, 彩礼
# 0.00 seconds, row 176, 大陆人 ALREADY EXISTS
# 0.00 seconds, row 177, 灯笼 ALREADY EXISTS
# 0.74 seconds, row 178, 党员
# 0.00 seconds, row 179, 方言 ALREADY EXISTS
# 0.00 seconds, row 180, 过年 ALREADY EXISTS
# 0.64 seconds, row 181, 广场舞
# 0.00 seconds, row 182, 猴年 ALREADY EXISTS
# 0.68 seconds, row 183, 户口
# 0.00 seconds, row 184, 老友记 ALREADY EXISTS
# 0.77 seconds, row 185, 美国华裔
# 0.00 seconds, row 186, 农历 ALREADY EXISTS
# 0.58 seconds, row 187, 烧香
# 0.00 seconds, row 188, 随地吐痰 ALREADY EXISTS
# 0.00 seconds, row 189, 王朝 ALREADY EXISTS
# 0.00 seconds, row 190, 相亲 ALREADY EXISTS
# 0.00 seconds, row 191, 缘分 ALREADY EXISTS
# 0.00 seconds, row 192, 烟花 ALREADY EXISTS
# 0.00 seconds, row 193, 短裤 ALREADY EXISTS
# 0.00 seconds, row 194, 大衣 ALREADY EXISTS
# 0.00 seconds, row 195, 口红 ALREADY EXISTS
# 0.00 seconds, row 196, 凉鞋 ALREADY EXISTS
# 0.00 seconds, row 197, 领带 ALREADY EXISTS
# 0.00 seconds, row 198, 墨镜 ALREADY EXISTS
# 0.00 seconds, row 199, 美容 ALREADY EXISTS
# 0.00 seconds, row 200, 內裤 ALREADY EXISTS
# 0.58 seconds, row 201, 内衣
# 0.00 seconds, row 202, 睡衣 ALREADY EXISTS
# 0.00 seconds, row 203, 手套 ALREADY EXISTS
# 0.00 seconds, row 204, 外套 ALREADY EXISTS
# 0.00 seconds, row 205, 项链 ALREADY EXISTS
# 0.00 seconds, row 206, 戏服 ALREADY EXISTS
# 0.00 seconds, row 207, 西装 ALREADY EXISTS
# 0.87 seconds, row 208, 亚麻布
# 0.00 seconds, row 209, 泳衣 ALREADY EXISTS
# 0.00 seconds, row 210, 斑马线 ALREADY EXISTS
# 0.00 seconds, row 211, 掉头 ALREADY EXISTS
# 0.00 seconds, row 212, 负一楼 ALREADY EXISTS
# 0.00 seconds, row 213, 方向感 ALREADY EXISTS
# 0.00 seconds, row 214, 回转 ALREADY EXISTS
# 0.00 seconds, row 215, 上坡 ALREADY EXISTS
# 0.00 seconds, row 216, 停车场 ALREADY EXISTS
# 0.00 seconds, row 217, 弯路 ALREADY EXISTS
# 0.00 seconds, row 218, 下坡 ALREADY EXISTS
# 0.00 seconds, row 219, 转身 ALREADY EXISTS
# 0.00 seconds, row 220, 表情包 ALREADY EXISTS
# 0.00 seconds, row 221, 爆红 ALREADY EXISTS
# 0.58 seconds, row 222, 播客
# 0.00 seconds, row 223, 博主 ALREADY EXISTS
# 0.00 seconds, row 224, 程序 ALREADY EXISTS
# 0.61 seconds, row 225, 插座
# 0.00 seconds, row 226, 充电宝 ALREADY EXISTS
# 0.00 seconds, row 227, 充电器 ALREADY EXISTS
# 0.81 seconds, row 228, 电缆
# 0.00 seconds, row 229, 电商 ALREADY EXISTS
# 0.00 seconds, row 230, 电压 ALREADY EXISTS
# 0.00 seconds, row 231, 电子表格 ALREADY EXISTS
# 0.00 seconds, row 232, 电子邮件 ALREADY EXISTS
# 0.65 seconds, row 233, 点击
# 0.62 seconds, row 234, 点赞
# 0.00 seconds, row 235, 订阅 ALREADY EXISTS
# 0.00 seconds, row 236, 登出 ALREADY EXISTS
# 0.00 seconds, row 237, 登录 ALREADY EXISTS
# 0.91 seconds, row 238, 防火墙
# 0.00 seconds, row 239, 分享 ALREADY EXISTS
# 0.00 seconds, row 240, 风扇 ALREADY EXISTS
# 0.00 seconds, row 241, 关机 ALREADY EXISTS
# 0.78 seconds, row 242, 交友软件
# 0.00 seconds, row 243, 计算机 ALREADY EXISTS
# 0.00 seconds, row 244, 机器人 ALREADY EXISTS
# 0.00 seconds, row 245, 链接 ALREADY EXISTS
# 0.00 seconds, row 246, 流量 ALREADY EXISTS
# 0.00 seconds, row 247, 浏览器 ALREADY EXISTS
# 0.64 seconds, row 248, 拉黑
# 0.66 seconds, row 249, 面部识别
# 0.67 seconds, row 250, 默认
# 0.00 seconds, row 251, 能源 ALREADY EXISTS
# 0.00 seconds, row 252, 排序 ALREADY EXISTS
# 0.00 seconds, row 253, 频道 ALREADY EXISTS
# 0.00 seconds, row 254, 评论 ALREADY EXISTS
# 0.62 seconds, row 255, 喷子
# 0.00 seconds, row 256, 软件 ALREADY EXISTS
# 0.00 seconds, row 257, 刷新 ALREADY EXISTS
# 0.00 seconds, row 258, 上传 ALREADY EXISTS
# 0.00 seconds, row 259, 设置 ALREADY EXISTS
# 0.00 seconds, row 260, 数码 ALREADY EXISTS
# 0.62 seconds, row 261, 数据库
# 0.71 seconds, row 262, 筛选
# 0.00 seconds, row 263, 输入 ALREADY EXISTS
# 0.00 seconds, row 264, 手表 ALREADY EXISTS
# 0.00 seconds, row 265, 首页 ALREADY EXISTS
# 0.00 seconds, row 266, 算法 ALREADY EXISTS
# 0.00 seconds, row 267, 太阳能 ALREADY EXISTS
# 0.00 seconds, row 268, 通知 ALREADY EXISTS
# 0.62 seconds, row 269, 网飞
# 0.00 seconds, row 270, 网红 ALREADY EXISTS
# 0.00 seconds, row 271, 网友 ALREADY EXISTS
# 0.00 seconds, row 272, 下载 ALREADY EXISTS
# 0.70 seconds, row 273, 线上
# 0.72 seconds, row 274, 线下
# 0.00 seconds, row 275, 信号 ALREADY EXISTS
# 0.00 seconds, row 276, 验证码 ALREADY EXISTS
# 0.00 seconds, row 277, 硬件 ALREADY EXISTS
# 0.00 seconds, row 278, 硬盘 ALREADY EXISTS
# 0.00 seconds, row 279, 用户 ALREADY EXISTS
# 0.00 seconds, row 280, 用户名 ALREADY EXISTS
# 0.00 seconds, row 281, 邮箱 ALREADY EXISTS
# 0.00 seconds, row 282, 转换器 ALREADY EXISTS
# 0.00 seconds, row 283, 账户 ALREADY EXISTS
# 0.64 seconds, row 284, 主页
# 0.00 seconds, row 285, 自动 ALREADY EXISTS
# 0.00 seconds, row 286, 字幕 ALREADY EXISTS
# 0.00 seconds, row 287, 二维码 ALREADY EXISTS
# 0.00 seconds, row 288, 安装 ALREADY EXISTS
# 0.00 seconds, row 289, 表情 ALREADY EXISTS
# 0.69 seconds, row 290, 抱怨
# 0.00 seconds, row 291, 不小心 ALREADY EXISTS
# 0.00 seconds, row 292, 不在乎 ALREADY EXISTS
# 0.00 seconds, row 293, 保证 ALREADY EXISTS
# 0.83 seconds, row 294, 沉迷于
# 0.00 seconds, row 295, 持怀疑态度 ALREADY EXISTS
# 0.00 seconds, row 296, 吵架 ALREADY EXISTS
# 0.62 seconds, row 297, 丢脸
# 0.00 seconds, row 298, 低估 ALREADY EXISTS
# 0.62 seconds, row 299, 放弃
# 0.67 seconds, row 300, 分心
# 0.68 seconds, row 301, 反应
# 0.80 seconds, row 302, 关心
# 0.00 seconds, row 303, 公平 ALREADY EXISTS
# 0.63 seconds, row 304, 孤独
# 0.00 seconds, row 305, 感人 ALREADY EXISTS
# 0.64 seconds, row 306, 搞笑
# 0.00 seconds, row 307, 后悔 ALREADY EXISTS
# 0.90 seconds, row 308, 介意
# 0.60 seconds, row 309, 焦虑
# 0.64 seconds, row 310, 看法
# 0.00 seconds, row 311, 困难 ALREADY EXISTS
# 0.00 seconds, row 312, 可靠 ALREADY EXISTS
# 0.72 seconds, row 313, 可疑
# 0.00 seconds, row 314, 理所当然 ALREADY EXISTS
# 0.00 seconds, row 315, 满意 ALREADY EXISTS
# 0.00 seconds, row 316, 敏感 ALREADY EXISTS
# 0.00 seconds, row 317, 难受 ALREADY EXISTS
# 0.00 seconds, row 318, 弄清楚 ALREADY EXISTS
# 0.00 seconds, row 319, 偏爱 ALREADY EXISTS
# 0.00 seconds, row 320, 期待 ALREADY EXISTS
# 0.00 seconds, row 321, 亲密 ALREADY EXISTS
# 0.67 seconds, row 322, 轻松
# 1.19 seconds, row 323, 视角
# 0.00 seconds, row 324, 适应 ALREADY EXISTS
# 0.00 seconds, row 325, 失望 ALREADY EXISTS
# 0.77 seconds, row 326, 贴心
# 0.00 seconds, row 327, 提醒 ALREADY EXISTS
# 0.00 seconds, row 328, 吐槽 ALREADY EXISTS
# 0.64 seconds, row 329, 微笑
# 0.00 seconds, row 330, 误会 ALREADY EXISTS
# 0.00 seconds, row 331, 想象 ALREADY EXISTS
# 0.00 seconds, row 332, 小看 ALREADY EXISTS
# 0.00 seconds, row 333, 细心 ALREADY EXISTS
# 0.63 seconds, row 334, 信任
# 0.65 seconds, row 335, 辛苦
# 0.00 seconds, row 336, 心情 ALREADY EXISTS
# 0.00 seconds, row 337, 心疼 ALREADY EXISTS
# 0.00 seconds, row 338, 原谅 ALREADY EXISTS
# 0.00 seconds, row 339, 意外 ALREADY EXISTS
# 0.60 seconds, row 340, 印象
# 0.00 seconds, row 341, 运气 ALREADY EXISTS
# 0.70 seconds, row 342, 仰慕
# 0.00 seconds, row 343, 语气 ALREADY EXISTS
# 0.00 seconds, row 344, 正好 ALREADY EXISTS
# 0.00 seconds, row 345, 重担 ALREADY EXISTS
# 0.00 seconds, row 346, 爆米花 ALREADY EXISTS
# 0.00 seconds, row 347, 白菜 ALREADY EXISTS
# 0.00 seconds, row 348, 冰沙 ALREADY EXISTS
# 0.00 seconds, row 349, 菠萝蜜 ALREADY EXISTS
# 0.79 seconds, row 350, 百香果
# 0.00 seconds, row 351, 保质期 ALREADY EXISTS
# 0.00 seconds, row 352, 饼干 ALREADY EXISTS
# 0.70 seconds, row 353, 成分
# 0.00 seconds, row 354, 成熟 ALREADY EXISTS
# 0.00 seconds, row 355, 菜花 ALREADY EXISTS
# 0.00 seconds, row 356, 餐具 ALREADY EXISTS
# 0.64 seconds, row 357, 草本
# 0.79 seconds, row 358, 蛋白质
# 0.63 seconds, row 359, 蛋黄
# 0.67 seconds, row 360, 蛋挞
# 0.00 seconds, row 361, 豆角 ALREADY EXISTS
# 0.00 seconds, row 362, 灯笼椒 ALREADY EXISTS
# 0.65 seconds, row 363, 果酱
# 0.65 seconds, row 364, 花生酱
# 0.77 seconds, row 365, 哈密​​瓜
# 0.64 seconds, row 366, 酱油
# 0.00 seconds, row 367, 加工的 ALREADY EXISTS
# 0.67 seconds, row 368, 加料
# 0.00 seconds, row 369, 煎饼 ALREADY EXISTS
# 0.00 seconds, row 370, 坚果 ALREADY EXISTS
# 0.00 seconds, row 371, 焦糖 ALREADY EXISTS
# 0.00 seconds, row 372, 碱水结 ALREADY EXISTS
# 0.00 seconds, row 373, 卷心菜 ALREADY EXISTS
# 0.00 seconds, row 374, 可乐 ALREADY EXISTS
# 0.00 seconds, row 375, 空气炸锅 ALREADY EXISTS
# 0.62 seconds, row 376, 烤肉
# 0.00 seconds, row 377, 烤箱 ALREADY EXISTS
# 0.00 seconds, row 378, 口水 ALREADY EXISTS
# 0.63 seconds, row 379, 口味
# 0.00 seconds, row 380, 口香糖 ALREADY EXISTS
# 0.00 seconds, row 381, 榴莲 ALREADY EXISTS
# 0.00 seconds, row 382, 龙眼 ALREADY EXISTS
# 0.00 seconds, row 383, 冷萃 ALREADY EXISTS
# 0.00 seconds, row 384, 棉花糖 ALREADY EXISTS
# 0.00 seconds, row 385, 毛豆 ALREADY EXISTS
# 0.74 seconds, row 386, 抹茶
# 0.00 seconds, row 387, 牛油果 ALREADY EXISTS
# 0.00 seconds, row 388, 拿走 ALREADY EXISTS
# 0.00 seconds, row 389, 农作物 ALREADY EXISTS
# 0.00 seconds, row 390, 泡菜 ALREADY EXISTS
# 0.63 seconds, row 391, 排骨
# 0.00 seconds, row 392, 葡萄干 ALREADY EXISTS
# 0.00 seconds, row 393, 拼配豆 ALREADY EXISTS
# 0.00 seconds, row 394, 秋葵 ALREADY EXISTS
# 0.00 seconds, row 395, 浅烘 ALREADY EXISTS
# 0.00 seconds, row 396, 气泡水 ALREADY EXISTS
# 0.00 seconds, row 397, 汽水 ALREADY EXISTS
# 0.00 seconds, row 398, 清真 ALREADY EXISTS
# 0.78 seconds, row 399, 曲奇
# 0.59 seconds, row 400, 肉桂
# 0.00 seconds, row 401, 剩菜 ALREADY EXISTS
# 0.00 seconds, row 402, 圣女果 ALREADY EXISTS
# 0.00 seconds, row 403, 食物中毒 ALREADY EXISTS
# 0.00 seconds, row 404, 深度烘焙 ALREADY EXISTS
# 0.63 seconds, row 405, 生菜
# 0.00 seconds, row 406, 手冲 ALREADY EXISTS
# 0.67 seconds, row 407, 薯片
# 0.00 seconds, row 408, 酸橙 ALREADY EXISTS
# 0.00 seconds, row 409, 素食 ALREADY EXISTS
# 0.00 seconds, row 410, 调味品 ALREADY EXISTS
# 0.81 seconds, row 411, 碳水化合物
# 0.00 seconds, row 412, 胃口 ALREADY EXISTS
# 0.00 seconds, row 413, 微波炉 ALREADY EXISTS
# 0.00 seconds, row 414, 维生素 ALREADY EXISTS
# 0.80 seconds, row 415, 乌龙茶
# 0.00 seconds, row 416, 香肠 ALREADY EXISTS
# 0.00 seconds, row 417, 香草 ALREADY EXISTS
# 0.68 seconds, row 418, 宵夜
# 0.00 seconds, row 419, 吸管 ALREADY EXISTS
# 0.00 seconds, row 420, 羊角面包 ALREADY EXISTS
# 0.00 seconds, row 421, 意式浓缩 ALREADY EXISTS
# 0.65 seconds, row 422, 硬糖
# 0.00 seconds, row 423, 营养 ALREADY EXISTS
# 0.00 seconds, row 424, 油桃 ALREADY EXISTS
# 0.00 seconds, row 425, 油炸 ALREADY EXISTS
# 0.00 seconds, row 426, 有毒 ALREADY EXISTS
# 0.00 seconds, row 427, 羽衣甘蓝 ALREADY EXISTS
# 0.83 seconds, row 428, 自助餐
# 0.00 seconds, row 429, 紫菜 ALREADY EXISTS
# 0.00 seconds, row 430, 变量 ALREADY EXISTS
# 0.00 seconds, row 431, 闭嘴 ALREADY EXISTS
# 0.64 seconds, row 432, 不幸
# 0.00 seconds, row 433, 不正常 ALREADY EXISTS
# 0.65 seconds, row 434, 保持
# 0.00 seconds, row 435, 从不 ALREADY EXISTS
# 0.63 seconds, row 436, 调查
# 0.00 seconds, row 437, 到处 ALREADY EXISTS
# 0.59 seconds, row 438, 分别
# 0.82 seconds, row 439, 分不清
# 0.00 seconds, row 440, 光滑 ALREADY EXISTS
# 0.62 seconds, row 441, 个人
# 0.00 seconds, row 442, 各种 ALREADY EXISTS
# 0.66 seconds, row 443, 更喜欢
# 0.00 seconds, row 444, 刚好 ALREADY EXISTS
# 0.62 seconds, row 445, 功能
# 0.00 seconds, row 446, 回电 ALREADY EXISTS
# 0.68 seconds, row 447, 核心
# 0.61 seconds, row 448, 胡说
# 0.58 seconds, row 449, 好像
# 0.00 seconds, row 450, 好转 ALREADY EXISTS
# 0.00 seconds, row 451, 假期 ALREADY EXISTS
# 0.00 seconds, row 452, 交流 ALREADY EXISTS
# 0.00 seconds, row 453, 假设 ALREADY EXISTS
# 0.00 seconds, row 454, 纪念日 ALREADY EXISTS
# 0.00 seconds, row 455, 具体 ALREADY EXISTS
# 0.00 seconds, row 456, 六边形 ALREADY EXISTS
# 0.62 seconds, row 457, 流行
# 0.00 seconds, row 458, 浪费 ALREADY EXISTS
# 0.00 seconds, row 459, 类似 ALREADY EXISTS
# 0.66 seconds, row 460, 另外
# 0.00 seconds, row 461, 轮流 ALREADY EXISTS
# 0.00 seconds, row 462, 麻烦 ALREADY EXISTS
# 0.00 seconds, row 463, 难免 ALREADY EXISTS
# 0.65 seconds, row 464, 确实
# 0.00 seconds, row 465, 取决于 ALREADY EXISTS
# 0.00 seconds, row 466, 取消 ALREADY EXISTS
# 0.00 seconds, row 467, 日常 ALREADY EXISTS
# 0.00 seconds, row 468, 身边 ALREADY EXISTS
# 0.00 seconds, row 469, 三角形 ALREADY EXISTS
# 0.00 seconds, row 470, 天堂 ALREADY EXISTS
# 0.00 seconds, row 471, 退化 ALREADY EXISTS
# 0.64 seconds, row 472, 偷偷
# 0.00 seconds, row 473, 体验 ALREADY EXISTS
# 0.00 seconds, row 474, 午睡 ALREADY EXISTS
# 0.00 seconds, row 475, 想起来 ALREADY EXISTS
# 0.00 seconds, row 476, 一再 ALREADY EXISTS
# 0.00 seconds, row 477, 英雄 ALREADY EXISTS
# 0.00 seconds, row 478, 有利 ALREADY EXISTS
# 0.00 seconds, row 479, 重视 ALREADY EXISTS
# 0.00 seconds, row 480, 之类 ALREADY EXISTS
# 0.00 seconds, row 481, 暂停 ALREADY EXISTS
# 0.00 seconds, row 482, 组成 ALREADY EXISTS
# 0.00 seconds, row 483, 组合 ALREADY EXISTS
# 0.67 seconds, row 484, 按照
# 0.65 seconds, row 485, 偶然
# 0.88 seconds, row 486, 半月板
# 0.00 seconds, row 487, 避孕套 ALREADY EXISTS
# 0.00 seconds, row 488, 病毒 ALREADY EXISTS
# 0.00 seconds, row 489, 病人 ALREADY EXISTS
# 0.60 seconds, row 490, 出汗
# 0.67 seconds, row 491, 大便
# 0.64 seconds, row 492, 大卡
# 0.00 seconds, row 493, 代谢 ALREADY EXISTS
# 0.62 seconds, row 494, 大麻
# 0.64 seconds, row 495, 发烧
# 0.00 seconds, row 496, 非处方药 ALREADY EXISTS
# 0.00 seconds, row 497, 感染 ALREADY EXISTS
# 0.00 seconds, row 498, 护士 ALREADY EXISTS
# 0.79 seconds, row 499, 救护车
# 0.00 seconds, row 500, 减肥 ALREADY EXISTS
# 0.79 seconds, row 501, 急诊室
# 0.00 seconds, row 502, 基因 ALREADY EXISTS
# 0.00 seconds, row 503, 狂犬病 ALREADY EXISTS
# 0.60 seconds, row 504, 看病
# 0.00 seconds, row 505, 口罩 ALREADY EXISTS
# 0.00 seconds, row 506, 流感 ALREADY EXISTS
# 0.00 seconds, row 507, 流血 ALREADY EXISTS
# 0.62 seconds, row 508, 轮椅
# 0.00 seconds, row 509, 拉肚子 ALREADY EXISTS
# 0.61 seconds, row 510, 拉尿
# 0.00 seconds, row 511, 拉伸 ALREADY EXISTS
# 0.59 seconds, row 512, 拉屎
# 0.61 seconds, row 513, 麻木
# 0.63 seconds, row 514, 门诊
# 0.00 seconds, row 515, 沐浴露 ALREADY EXISTS
# 0.00 seconds, row 516, 尿布 ALREADY EXISTS
# 0.00 seconds, row 517, 农药 ALREADY EXISTS
# 0.00 seconds, row 518, 器官 ALREADY EXISTS
# 0.00 seconds, row 519, 受伤 ALREADY EXISTS
# 0.00 seconds, row 520, 杀菌 ALREADY EXISTS
# 0.62 seconds, row 521, 伤害
# 0.00 seconds, row 522, 生理 ALREADY EXISTS
# 0.63 seconds, row 523, 生育
# 0.00 seconds, row 524, 输精管除术 ALREADY EXISTS
# 0.00 seconds, row 525, 手术 ALREADY EXISTS
# 0.00 seconds, row 526, 体毛 ALREADY EXISTS
# 0.00 seconds, row 527, 卫生棉条 ALREADY EXISTS
# 0.63 seconds, row 528, 胃痛
# 0.00 seconds, row 529, 血管 ALREADY EXISTS
# 0.64 seconds, row 530, 小便
# 0.00 seconds, row 531, 性别 ALREADY EXISTS
# 0.61 seconds, row 532, 性病
# 0.76 seconds, row 533, 洗手液
# 0.00 seconds, row 534, 验血 ALREADY EXISTS
# 0.66 seconds, row 535, 药剂
# 0.67 seconds, row 536, 药师
# 0.00 seconds, row 537, 药丸 ALREADY EXISTS
# 0.00 seconds, row 538, 牙刷 ALREADY EXISTS
# 0.00 seconds, row 539, 疫苗 ALREADY EXISTS
# 0.00 seconds, row 540, 疫情 ALREADY EXISTS
# 0.00 seconds, row 541, 医保 ALREADY EXISTS
# 0.64 seconds, row 542, 着凉
# 0.00 seconds, row 543, 症状 ALREADY EXISTS
# 0.00 seconds, row 544, 住院 ALREADY EXISTS
# 0.00 seconds, row 545, 住院 ALREADY EXISTS
# 0.00 seconds, row 546, 诊所 ALREADY EXISTS
# 0.63 seconds, row 547, 指纹
# 0.63 seconds, row 548, 额头
# 0.64 seconds, row 549, 安全套
# 0.00 seconds, row 550, 恶心 ALREADY EXISTS
# 0.00 seconds, row 551, 电视 ALREADY EXISTS
# 0.00 seconds, row 552, 歌词 ALREADY EXISTS
# 0.00 seconds, row 553, 画廊 ALREADY EXISTS
# 0.00 seconds, row 554, 互动 ALREADY EXISTS
# 0.00 seconds, row 555, 纪录片 ALREADY EXISTS
# 0.00 seconds, row 556, 文学 ALREADY EXISTS
# 0.00 seconds, row 557, 相机 ALREADY EXISTS
# 0.00 seconds, row 558, 心理 ALREADY EXISTS
# 0.65 seconds, row 559, 喜剧
# 0.00 seconds, row 560, 乐队 ALREADY EXISTS
# 0.00 seconds, row 561, 游泳池 ALREADY EXISTS
# 0.00 seconds, row 562, 哲学 ALREADY EXISTS
# 0.00 seconds, row 563, 自拍 ALREADY EXISTS
# 0.00 seconds, row 564, 不环保 ALREADY EXISTS
# 0.00 seconds, row 565, 工厂 ALREADY EXISTS
# 0.61 seconds, row 566, 破产
# 0.00 seconds, row 567, 水泥 ALREADY EXISTS
# 0.59 seconds, row 568, 设施
# 0.00 seconds, row 569, 标点 ALREADY EXISTS
# 0.00 seconds, row 570, 成语 ALREADY EXISTS
# 0.00 seconds, row 571, 粗话 ALREADY EXISTS
# 0.00 seconds, row 572, 定义 ALREADY EXISTS
# 0.00 seconds, row 573, 发音 ALREADY EXISTS
# 0.00 seconds, row 574, 概括 ALREADY EXISTS
# 0.00 seconds, row 575, 回信 ALREADY EXISTS
# 0.58 seconds, row 576, 后缀
# 0.00 seconds, row 577, 后者 ALREADY EXISTS
# 0.00 seconds, row 578, 简介 ALREADY EXISTS
# 0.58 seconds, row 579, 口吻
# 0.00 seconds, row 580, 名声 ALREADY EXISTS
# 0.00 seconds, row 581, 名言 ALREADY EXISTS
# 0.00 seconds, row 582, 女权主义 ALREADY EXISTS
# 0.58 seconds, row 583, 前缀
# 0.00 seconds, row 584, 前者 ALREADY EXISTS
# 0.63 seconds, row 585, 说法
# 0.00 seconds, row 586, 十分 ALREADY EXISTS
# 0.00 seconds, row 587, 声调 ALREADY EXISTS
# 0.63 seconds, row 588, 输入法
# 0.00 seconds, row 589, 缩写 ALREADY EXISTS
# 0.67 seconds, row 590, 外语
# 0.00 seconds, row 591, 未来 ALREADY EXISTS
# 0.80 seconds, row 592, 谐音梗
# 0.00 seconds, row 593, 习语 ALREADY EXISTS
# 0.00 seconds, row 594, 形容词 ALREADY EXISTS
# 0.00 seconds, row 595, 语法 ALREADY EXISTS
# 0.00 seconds, row 596, 语气词 ALREADY EXISTS
# 0.00 seconds, row 597, 语序 ALREADY EXISTS
# 0.00 seconds, row 598, 直译词 ALREADY EXISTS
# 0.00 seconds, row 599, 字典 ALREADY EXISTS
# 0.00 seconds, row 600, 字母 ALREADY EXISTS
# 0.00 seconds, row 601, 变睡着 ALREADY EXISTS
# 0.00 seconds, row 602, 半夜 ALREADY EXISTS
# 0.00 seconds, row 603, 本地 ALREADY EXISTS
# 0.00 seconds, row 604, 保险 ALREADY EXISTS
# 0.00 seconds, row 605, 床单 ALREADY EXISTS
# 0.62 seconds, row 606, 窗帘
# 0.00 seconds, row 607, 吹风机 ALREADY EXISTS
# 0.60 seconds, row 608, 成年
# 0.00 seconds, row 609, 重新装修 ALREADY EXISTS
# 0.00 seconds, row 610, 车库 ALREADY EXISTS
# 0.00 seconds, row 611, 车牌 ALREADY EXISTS
# 0.62 seconds, row 612, 单身
# 0.00 seconds, row 613, 打火机 ALREADY EXISTS
# 0.00 seconds, row 614, 房贷 ALREADY EXISTS
# 0.63 seconds, row 615, 风险
# 0.66 seconds, row 616, 花销
# 0.00 seconds, row 617, 合同 ALREADY EXISTS
# 0.66 seconds, row 618, 烘干
# 0.65 seconds, row 619, 婚礼
# 0.00 seconds, row 620, 间隔年 ALREADY EXISTS
# 0.64 seconds, row 621, 家务
# 0.60 seconds, row 622, 经历
# 0.00 seconds, row 623, 客厅 ALREADY EXISTS
# 0.00 seconds, row 624, 求婚 ALREADY EXISTS
# 0.76 seconds, row 625, 热水器
# 0.00 seconds, row 626, 日程 ALREADY EXISTS
# 0.00 seconds, row 627, 日用品 ALREADY EXISTS
# 0.00 seconds, row 628, 水壶 ALREADY EXISTS
# 0.00 seconds, row 629, 水龙头 ALREADY EXISTS
# 0.00 seconds, row 630, 事故 ALREADY EXISTS
# 0.00 seconds, row 631, 室内 ALREADY EXISTS
# 0.00 seconds, row 632, 时间表 ALREADY EXISTS
# 0.62 seconds, row 633, 生活成本
# 0.62 seconds, row 634, 生活方式
# 0.60 seconds, row 635, 书架
# 0.00 seconds, row 636, 书桌 ALREADY EXISTS
# 0.58 seconds, row 637, 调情
# 0.00 seconds, row 638, 台阶 ALREADY EXISTS
# 0.00 seconds, row 639, 同母异父 ALREADY EXISTS
# 0.60 seconds, row 640, 维修
# 0.64 seconds, row 641, 现金
# 0.00 seconds, row 642, 约会 ALREADY EXISTS
# 0.00 seconds, row 643, 阳台 ALREADY EXISTS
# 0.00 seconds, row 644, 衣柜 ALREADY EXISTS
# 0.00 seconds, row 645, 装饰品 ALREADY EXISTS
# 0.63 seconds, row 646, 装修
# 0.00 seconds, row 647, 照顾 ALREADY EXISTS
# 0.67 seconds, row 648, 枕头
# 0.63 seconds, row 649, 中年
# 0.00 seconds, row 650, 长大 ALREADY EXISTS
# 0.00 seconds, row 651, 纸巾 ALREADY EXISTS
# 0.00 seconds, row 652, 杂物 ALREADY EXISTS
# 0.00 seconds, row 653, 租赁合同 ALREADY EXISTS
# 0.64 seconds, row 654, 熬夜
# 0.00 seconds, row 655, 后果 ALREADY EXISTS
# 0.62 seconds, row 656, 结果
# 0.60 seconds, row 657, 模型
# 0.00 seconds, row 658, 手势 ALREADY EXISTS
# 0.00 seconds, row 659, 冰川 ALREADY EXISTS
# 0.00 seconds, row 660, 创新高 ALREADY EXISTS
# 0.00 seconds, row 661, 草丛 ALREADY EXISTS
# 0.00 seconds, row 662, 对手 ALREADY EXISTS
# 0.00 seconds, row 663, 地震 ALREADY EXISTS
# 0.00 seconds, row 664, 防晒霜 ALREADY EXISTS
# 0.00 seconds, row 665, 发球 ALREADY EXISTS
# 0.58 seconds, row 666, 风暴
# 0.58 seconds, row 667, 公众场合
# 0.00 seconds, row 668, 滑雪 ALREADY EXISTS
# 0.00 seconds, row 669, 滑雪板 ALREADY EXISTS
# 0.00 seconds, row 670, 花园 ALREADY EXISTS
# 0.00 seconds, row 671, 火山 ALREADY EXISTS
# 0.00 seconds, row 672, 健身 ALREADY EXISTS
# 0.61 seconds, row 673, 凉快
# 0.59 seconds, row 674, 满月
# 0.76 seconds, row 675, 人行道
# 0.00 seconds, row 676, 日落 ALREADY EXISTS
# 0.00 seconds, row 677, 水库 ALREADY EXISTS
# 0.00 seconds, row 678, 晒伤 ALREADY EXISTS
# 0.00 seconds, row 679, 树枝 ALREADY EXISTS
# 0.00 seconds, row 680, 树荫 ALREADY EXISTS
# 0.00 seconds, row 681, 湿度 ALREADY EXISTS
# 0.65 seconds, row 682, 台风
# 0.00 seconds, row 683, 体育场 ALREADY EXISTS
# 0.66 seconds, row 684, 自然灾害
# 0.61 seconds, row 685, 自卫
# 0.00 seconds, row 686, 不信教 ALREADY EXISTS
# 0.62 seconds, row 687, 保守
# 0.00 seconds, row 688, 出轨 ALREADY EXISTS
# 0.00 seconds, row 689, 担心 ALREADY EXISTS
# 0.72 seconds, row 690, 烦人
# 0.00 seconds, row 691, 夫妻 ALREADY EXISTS
# 0.00 seconds, row 692, 过度 ALREADY EXISTS
# 0.59 seconds, row 693, 鼓励
# 0.58 seconds, row 694, 借口
# 0.00 seconds, row 695, 假装 ALREADY EXISTS
# 0.00 seconds, row 696, 轮流 ALREADY EXISTS
# 0.57 seconds, row 697, 盲区
# 0.58 seconds, row 698, 默契
# 0.58 seconds, row 699, 陌生人
# 0.00 seconds, row 700, 内向 ALREADY EXISTS
# 0.00 seconds, row 701, 偏见 ALREADY EXISTS
# 0.00 seconds, row 702, 评价 ALREADY EXISTS
# 0.00 seconds, row 703, 舍友 ALREADY EXISTS
# 0.00 seconds, row 704, 同志 ALREADY EXISTS
# 0.00 seconds, row 705, 同性恋 ALREADY EXISTS
# 0.58 seconds, row 706, 姓名
# 0.00 seconds, row 707, 摇头 ALREADY EXISTS
# 0.00 seconds, row 708, 异地恋 ALREADY EXISTS
# 0.00 seconds, row 709, 意见 ALREADY EXISTS
# 0.00 seconds, row 710, 有名 ALREADY EXISTS
# 0.00 seconds, row 711, 装傻 ALREADY EXISTS
# 0.00 seconds, row 712, 争论 ALREADY EXISTS
# 0.73 seconds, row 713, 主持人
# 0.00 seconds, row 714, 自觉 ALREADY EXISTS
# 0.00 seconds, row 715, 租客 ALREADY EXISTS
# 0.00 seconds, row 716, 安家 ALREADY EXISTS
# 0.00 seconds, row 717, 安排 ALREADY EXISTS
# 0.00 seconds, row 718, 沙特 ALREADY EXISTS
# 0.00 seconds, row 719, 商场 ALREADY EXISTS
# 0.72 seconds, row 720, 乌克兰
# 0.00 seconds, row 721, 中东 ALREADY EXISTS
# 0.58 seconds, row 722, 惊喜
# 0.00 seconds, row 723, 没错 ALREADY EXISTS
# 0.58 seconds, row 724, 难怪
# 0.00 seconds, row 725, 说不定 ALREADY EXISTS
# 0.57 seconds, row 726, 他妈
# 0.00 seconds, row 727, 无论 ALREADY EXISTS
# 0.57 seconds, row 728, 包邮
# 0.00 seconds, row 729, 包装 ALREADY EXISTS
# 0.00 seconds, row 730, 烘焙店 ALREADY EXISTS
# 0.58 seconds, row 731, 连锁店
# 0.77 seconds, row 732, 卖完了
# 0.64 seconds, row 733, 品牌
# 0.00 seconds, row 734, 税前 ALREADY EXISTS
# 0.00 seconds, row 735, 试用期 ALREADY EXISTS
# 0.00 seconds, row 736, 退货 ALREADY EXISTS
# 0.00 seconds, row 737, 特色 ALREADY EXISTS
# 0.00 seconds, row 738, 停产 ALREADY EXISTS
# 0.00 seconds, row 739, 消费 ALREADY EXISTS
# 0.00 seconds, row 740, 性价比 ALREADY EXISTS
# 0.00 seconds, row 741, 样品 ALREADY EXISTS
# 0.00 seconds, row 742, 夜市 ALREADY EXISTS
# 0.64 seconds, row 743, 议价
# 0.00 seconds, row 744, 应用 ALREADY EXISTS
# 0.62 seconds, row 745, 预约
# 0.00 seconds, row 746, 已售 ALREADY EXISTS
# 0.57 seconds, row 747, 支装
# 0.00 seconds, row 748, 传言 ALREADY EXISTS
# 0.00 seconds, row 749, 丑闻 ALREADY EXISTS
# 0.00 seconds, row 750, 彩票 ALREADY EXISTS
# 0.73 seconds, row 751, 多样化
# 0.00 seconds, row 752, 代表 ALREADY EXISTS
# 0.73 seconds, row 753, 单亲妈妈
# 0.59 seconds, row 754, 房地产开发
# 0.57 seconds, row 755, 佛教
# 0.58 seconds, row 756, 发达
# 0.00 seconds, row 757, 非法 ALREADY EXISTS
# 0.00 seconds, row 758, 腐败 ALREADY EXISTS
# 0.00 seconds, row 759, 关税 ALREADY EXISTS
# 0.00 seconds, row 760, 革命 ALREADY EXISTS
# 0.57 seconds, row 761, 公告
# 0.00 seconds, row 762, 火箭 ALREADY EXISTS
# 0.00 seconds, row 763, 合法 ALREADY EXISTS
# 0.57 seconds, row 764, 和平
# 0.58 seconds, row 765, 合作社
# 0.00 seconds, row 766, 教堂 ALREADY EXISTS
# 0.58 seconds, row 767, 交警
# 0.00 seconds, row 768, 纪念碑 ALREADY EXISTS
# 0.00 seconds, row 769, 俱乐部 ALREADY EXISTS
# 0.00 seconds, row 770, 基础设施 ALREADY EXISTS
# 0.75 seconds, row 771, 基督教
# 0.57 seconds, row 772, 军队
# 0.58 seconds, row 773, 警察
# 0.00 seconds, row 774, 可回收 ALREADY EXISTS
# 0.00 seconds, row 775, 可再生能源 ALREADY EXISTS
# 0.00 seconds, row 776, 矛盾 ALREADY EXISTS
# 0.58 seconds, row 777, 媒体
# 0.57 seconds, row 778, 歧视
# 0.58 seconds, row 779, 起诉
# 0.57 seconds, row 780, 人口
# 0.00 seconds, row 781, 社区 ALREADY EXISTS
# 0.00 seconds, row 782, 神话 ALREADY EXISTS
# 0.00 seconds, row 783, 实用 ALREADY EXISTS
# 0.00 seconds, row 784, 身份证 ALREADY EXISTS
# 0.58 seconds, row 785, 生育率
# 0.00 seconds, row 786, 少数民族 ALREADY EXISTS
# 0.58 seconds, row 787, 外界
# 0.00 seconds, row 788, 外交 ALREADY EXISTS
# 0.00 seconds, row 789, 王子 ALREADY EXISTS
# 0.00 seconds, row 790, 危机 ALREADY EXISTS
# 0.00 seconds, row 791, 现代 ALREADY EXISTS
# 0.60 seconds, row 792, 效率
# 0.00 seconds, row 793, 闲聊 ALREADY EXISTS
# 0.00 seconds, row 794, 新闻 ALREADY EXISTS
# 0.00 seconds, row 795, 一战 ALREADY EXISTS
# 0.57 seconds, row 796, 有钱
# 0.57 seconds, row 797, 政策
# 0.58 seconds, row 798, 制度
# 0.00 seconds, row 799, 值得 ALREADY EXISTS
# 0.00 seconds, row 800, 总理 ALREADY EXISTS
# 0.00 seconds, row 801, 二战 ALREADY EXISTS
# 0.00 seconds, row 802, 把手 ALREADY EXISTS
# 0.00 seconds, row 803, 地毯 ALREADY EXISTS
# 0.00 seconds, row 804, 奖杯 ALREADY EXISTS
# 0.00 seconds, row 805, 净重 ALREADY EXISTS
# 0.00 seconds, row 806, 喷泉 ALREADY EXISTS
# 0.00 seconds, row 807, 钱包 ALREADY EXISTS
# 0.58 seconds, row 808, 水坑
# 0.00 seconds, row 809, 设备 ALREADY EXISTS
# 0.00 seconds, row 810, 武器 ALREADY EXISTS
# 0.00 seconds, row 811, 香水 ALREADY EXISTS
# 0.00 seconds, row 812, 原料 ALREADY EXISTS
# 0.57 seconds, row 813, 遥控
# 0.57 seconds, row 814, 杂志
# 0.58 seconds, row 815, 长期
# 0.00 seconds, row 816, 初步 ALREADY EXISTS
# 0.57 seconds, row 817, 点钟
# 0.00 seconds, row 818, 动态 ALREADY EXISTS
# 0.00 seconds, row 819, 当代 ALREADY EXISTS
# 0.00 seconds, row 820, 当前 ALREADY EXISTS
# 0.57 seconds, row 821, 儿时
# 0.57 seconds, row 822, 工作日
# 0.00 seconds, row 823, 计时器 ALREADY EXISTS
# 0.00 seconds, row 824, 近日 ALREADY EXISTS
# 0.00 seconds, row 825, 即将 ALREADY EXISTS
# 0.00 seconds, row 826, 六十年代 ALREADY EXISTS
# 0.58 seconds, row 827, 临时
# 0.57 seconds, row 828, 目前
# 0.00 seconds, row 829, 平时 ALREADY EXISTS
# 0.00 seconds, row 830, 日历 ALREADY EXISTS
# 0.00 seconds, row 831, 日期 ALREADY EXISTS
# 0.00 seconds, row 832, 上旬 ALREADY EXISTS
# 0.00 seconds, row 833, 世纪 ALREADY EXISTS
# 0.59 seconds, row 834, 事先
# 0.00 seconds, row 835, 随时 ALREADY EXISTS
# 0.00 seconds, row 836, 速度 ALREADY EXISTS
# 0.00 seconds, row 837, 推迟 ALREADY EXISTS
# 0.00 seconds, row 838, 下旬 ALREADY EXISTS
# 0.00 seconds, row 839, 月初 ALREADY EXISTS
# 0.00 seconds, row 840, 月底 ALREADY EXISTS
# 0.00 seconds, row 841, 以来 ALREADY EXISTS
# 0.00 seconds, row 842, 至今 ALREADY EXISTS
# 0.00 seconds, row 843, 至今 ALREADY EXISTS
# 0.00 seconds, row 844, 周期 ALREADY EXISTS
# 0.00 seconds, row 845, 准时 ALREADY EXISTS
# 0.00 seconds, row 846, 最初 ALREADY EXISTS
# 0.00 seconds, row 847, 暂时 ALREADY EXISTS
# 0.00 seconds, row 848, 按时 ALREADY EXISTS
# 0.00 seconds, row 849, 城堡 ALREADY EXISTS
# 0.58 seconds, row 850, 车位
# 0.58 seconds, row 851, 参观
# 0.58 seconds, row 852, 大使馆
# 0.00 seconds, row 853, 大堂 ALREADY EXISTS
# 0.58 seconds, row 854, 地点
# 0.57 seconds, row 855, 地址
# 0.58 seconds, row 856, 渡船
# 0.00 seconds, row 857, 导游 ALREADY EXISTS
# 0.00 seconds, row 858, 堵车 ALREADY EXISTS
# 0.65 seconds, row 859, 国旗
# 0.00 seconds, row 860, 航空公司 ALREADY EXISTS
# 0.00 seconds, row 861, 航站楼 ALREADY EXISTS
# 0.00 seconds, row 862, 后备箱 ALREADY EXISTS
# 0.64 seconds, row 863, 海外
# 0.00 seconds, row 864, 纪念品 ALREADY EXISTS
# 0.66 seconds, row 865, 居住证
# 0.57 seconds, row 866, 卡车
# 0.00 seconds, row 867, 流浪 ALREADY EXISTS
# 0.58 seconds, row 868, 路标
# 0.58 seconds, row 869, 缆车
# 0.59 seconds, row 870, 旅居
# 0.59 seconds, row 871, 旅游团
# 0.00 seconds, row 872, 气候 ALREADY EXISTS
# 0.00 seconds, row 873, 汽油 ALREADY EXISTS
# 0.00 seconds, row 874, 起飞 ALREADY EXISTS
# 0.00 seconds, row 875, 入住 ALREADY EXISTS
# 0.00 seconds, row 876, 沙漠 ALREADY EXISTS
# 0.58 seconds, row 877, 首都
# 0.00 seconds, row 878, 随身 ALREADY EXISTS
# 0.00 seconds, row 879, 天气预报 ALREADY EXISTS
# 0.73 seconds, row 880, 唐人街
# 0.00 seconds, row 881, 头等舱 ALREADY EXISTS
# 0.00 seconds, row 882, 问路 ALREADY EXISTS
# 0.00 seconds, row 883, 往返 ALREADY EXISTS
# 0.00 seconds, row 884, 乡村 ALREADY EXISTS
# 0.00 seconds, row 885, 小费 ALREADY EXISTS
# 0.00 seconds, row 886, 信用卡 ALREADY EXISTS
# 0.00 seconds, row 887, 行李 ALREADY EXISTS
# 0.00 seconds, row 888, 行李箱 ALREADY EXISTS
# 0.00 seconds, row 889, 移民 ALREADY EXISTS
# 0.57 seconds, row 890, 晕车
# 0.00 seconds, row 891, 早高峰 ALREADY EXISTS
# 0.00 seconds, row 892, 安全带 ALREADY EXISTS
# 0.00 seconds, row 893, 打断 ALREADY EXISTS
# 0.63 seconds, row 894, 发现
# 0.00 seconds, row 895, 反对 ALREADY EXISTS
# 0.00 seconds, row 896, 反思 ALREADY EXISTS
# 0.59 seconds, row 897, 纪念
# 0.00 seconds, row 898, 考虑 ALREADY EXISTS
# 0.00 seconds, row 899, 理解 ALREADY EXISTS
# 0.00 seconds, row 900, 说明 ALREADY EXISTS
# 0.00 seconds, row 901, 提出 ALREADY EXISTS
# 0.59 seconds, row 902, 提到
# 0.00 seconds, row 903, 提供 ALREADY EXISTS
# 0.00 seconds, row 904, 提示 ALREADY EXISTS
# 0.58 seconds, row 905, 偷走
# 0.61 seconds, row 906, 维持
# 0.58 seconds, row 907, 修改
# 0.00 seconds, row 908, 预报 ALREADY EXISTS
# 0.00 seconds, row 909, 造成 ALREADY EXISTS
# 0.00 seconds, row 910, 自杀 ALREADY EXISTS
# 0.59 seconds, row 911, 撒娇

# %%
# os.remove('audio_files/zh/经纪.mp3')

# %% [markdown]
# # 5. Combine individual vocab into final audio recording

# %%
# Combine the audio files into a single file
all_audio_files = []
for i_row, row in df_this.iterrows():
    audio_file = f"audio_files/rows/{recording_id}_{row['chinese']}.mp3"
    if os.path.exists(audio_file):
        all_audio_files.append(AudioSegment.from_mp3(audio_file))

combined = all_audio_files[0]
for audio in all_audio_files[1:]:
    combined += audio
combined.export(f"audio_files/products/{recording_id}_{recording_name}.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='audio_files/products/006_0815_word_p2_k2_ecombo.mp3'>

# %% [markdown]
# # 6.
